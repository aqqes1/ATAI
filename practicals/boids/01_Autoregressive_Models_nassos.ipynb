# %% [markdown]
# # Autoregressive Models
#
# In this practical, we'll go over the following topics:
# - Autoregressive models and when to use them
# - Implementing equivariances in Autoregressive GNNs
# - Evaluating scientific AI models
#
# But first, a short introduction on the dataset used for this practical.
#
# ![Boids gif](figures/boids.gif)
#
# ## Boids (by Craig Reynolds)
#
# The Boids algorithm, developed by Craig Reynolds [2], aims to replicate the behavior of flocking birds.
#
# The simplest setting, used in this practical, follows three simple rules:
#
# 1. Separation: Each boid should steer away from crowding local flockmates (avoiding collisions)
# 2. Alignment: Each boid should steer towards the average heading of local flockmates
# 3. Cohesion: Each boid should steer towards the average position of local flockmates
#
# With some parameter tuning, these rules allow for some surprisingly realistic behavior. A gif of one of the simulations is shown above.
#
# ### Implementation details
#
# Our dataset consists of 1000 samples of Boids simulations. Each simulation has 25 Boids and continues for 1000 timesteps. The Boids fly around in a 2D grid of 1000 x 1000 units.
#
# In our simulations, Boids steer away from eachother (Separation) if they are within 16 units of eachother. Boids steer towards the average heading/position of all (local) flockmates within 40 units.*
# Finally, we use periodic boundary conditions; Boids cannot leave the screen, they re-enter on the other side (pacman style).
#
# * We use Euclidean distance (with PBC) here to compute the distance between boids. For a more detailed explanation, visit [The minimum image convention](https://en.wikibooks.org/wiki/Molecular_Simulation/Periodic_Boundary_Conditions) section of the wikibooks page on PBC.
#
# ## Problem setting
#
# Boids simulations feature complex interactions between multiple actors (nodes). The simulation can be chaotic and very sensitive to initial conditions.
#
#
# This makes it an interesting playground for the models/frameworks discussed in the course. In this practical, we will implement an AR model from scratch, then gradually introduce equivariances and training/evaluation methods.

# %%
import torch 
import torch_geometric
from torch_geometric.data import Data, DataLoader, InMemoryDataset
import numpy as np
import matplotlib.pyplot as plt
import os
from torch_scatter import scatter_mean, scatter_sum
# Out:
# C:\Users\nasso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch_geometric\typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: Could not find module 'C:\Users\nasso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch_cluster\_grid_cuda.pyd' (or one of its dependencies). Try using the full path with constructor syntax.
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# C:\Users\nasso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch_geometric\typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: Could not find module 'C:\Users\nasso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch_spline_conv\_basis_cuda.pyd' (or one of its dependencies). Try using the full path with constructor syntax.
#   warnings.warn(
# C:\Users\nasso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch_geometric\typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: Could not find module 'C:\Users\nasso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch_sparse\_convert_cuda.pyd' (or one of its dependencies). Try using the full path with constructor syntax.
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "

# %% [markdown]
# ## Data exploration
#
# First let's look at the data structure, and some statistics.

# %%
trajectories = [np.load(f"../../data/boids/raw/{f}") for f in os.listdir("../../data/boids/raw") if f.endswith(".npy")]
print(len(trajectories))
# Out:
# 26

# %%
print("Single trajectory shape:")
print(trajectories[0].shape)
print("The axes and their cardinalities; (Timesteps:1000, Boids:25, (Position X, Position Y, Velocity x, Velocity y):4)")
# Out:
# Single trajectory shape:
# (1000, 25, 4)
# The axes and their cardinalities; (Timesteps:1000, Boids:25, (Position X, Position Y, Velocity x, Velocity y):4)

# %%
# Print the mean, std, min and max of the boid positions, velocities
positions = np.array([t[:, :, :2] for t in trajectories])
velocities = np.array([t[:, :, 2:] for t in trajectories])

print("Position mean, std, min, max:")
# Round to 2 decimal places
print(round(np.mean(positions),2), round(np.std(positions),2), round(np.min(positions), 2), round(np.max(positions), 2))
print()
print("Velocity mean, std, min, max:")
# Round to 2 decimal places
print(round(np.mean(velocities),2), round(np.std(velocities),2), round(np.min(velocities), 2), round(np.max(velocities), 2))
# Out:
# Position mean, std, min, max:
# 500.32 290.61 0.0 1000.0
#
# Velocity mean, std, min, max:
# -0.35 2.96 -6.0 6.0

# %%
def plot_state(trajectory, timestep):
    fig, ax = plt.subplots()
    # Plot dots for the boids
    ax.scatter(trajectory[timestep, :, 0], trajectory[timestep, :, 1])
    # plot the boid velocities as arrows
    for i in range(trajectory.shape[1]):
        # NOTE: The arrows are made larger for effect
        ax.arrow(trajectory[timestep, i, 0], trajectory[timestep, i, 1], trajectory[timestep, i, 2]*5, trajectory[timestep, i, 3]*5)
    return ax

# %%
# Plot timesteps 0, 250, 500, 750, 999 for the first trajectory
trajectory = trajectories[0]
fig, axs = plt.subplots(1, 5, figsize=(20, 4))
for i, t in enumerate([0, 250, 500, 750, 999]):
    axs[i].set_title(f"Timestep {t}")
    # Plot dots for the boids
    axs[i].scatter(trajectory[t, :, 0], trajectory[t, :, 1])
    # plot the boid velocities as arrows
    for j in range(trajectory.shape[1]):
        # NOTE: The arrows are made larger for effect
        axs[i].arrow(trajectory[t, j, 0], trajectory[t, j, 1], trajectory[t, j, 2]*5, trajectory[t, j, 3]*5)
plt.show()

# %% [markdown]
# In the plot above, you can see that after some warmup time, the boids start to form flocks. Flocking behavior is a form of inter-node communication, which we will come back to again later.
#
# Thinking back to the Geometric Deep Learning framework, we can identify the following symmetries in the data:
#
# - The boids are equivariant to permutations, ie it does not matter in which order we compute the update rules for the boids.
# - Local flocks of boids are equivariant to translation, rotation and reflection.
#
# Following these symmetries, it makes sense to model the boids using a Graph Neural Network (GNN). Specifically, since we are dealing with inter-node communication, we will be implementing a Message Passing GNN here.
#
# But first, we create a `torch_geometric` InMemoryDataset object, to model the data as a graph.

# %%
class AR_Boids_Dataset(InMemoryDataset):
    def __init__(self, raw_data_path, processed_data_path, root=None, transform=None, pre_transform=None, post_transform=None, solution_idx_range=(0, 25), timesteps=1000, processed_file_name="AR1_Boids.pt"):
        self.raw_data_path = raw_data_path
        self.processed_data_path = processed_data_path
        self.solution_idx_range = solution_idx_range
        self.timesteps = timesteps
        self.processed_file_name = processed_file_name
        self.pre_transform = pre_transform
        self.transform = transform
        self.post_transform = post_transform
        super(AR_Boids_Dataset, self).__init__(root, transform, pre_transform)
        self.data, self.slices = torch.load(self.processed_paths[0], weights_only=False) #TODO check this

    @property
    def processed_file_names(self):
        return [self.processed_file_name]

    @property
    def raw_file_names(self):
        return [pfn for pfn in os.listdir(self.raw_data_path) if (self.solution_idx_range[0] <= int(pfn.split("_")[-1][:-4]) < self.solution_idx_range[1])]
    
    def download(self):
        pass
    
    def __len__(self):
        return (self.timesteps - 1) * (self.solution_idx_range[1] - self.solution_idx_range[0])

    def process(self):
        data_list = []
        for idx, raw_path in enumerate(self.raw_file_names):
            trajectory = np.load(self.raw_data_path + raw_path)

            if self.transform is not None:
                trajectory = self.transform(trajectory)

            for t in range(trajectory.shape[0] - 1):
                x = torch.tensor(trajectory[t], dtype=torch.float)
                y_temp = torch.tensor(trajectory[t+1], dtype=torch.float)
                # y_temp is (position x, position y, velocity x, velocity y) for the next timestep
                # However, we want delta position and delta velocity
                # Luckily, the delta poisition is just the velocity from the next timestep, and the delta velocity is the acceleration
                # So we can just take the last two elements of y to get the delta velocity
                # First we copy the last two columns of y to the first two columns of y
                y = y_temp.clone()
                y[:, :2] = y_temp[:, 2:]
                # Then we calculate the acceleration
                y[:, 2:] = y_temp[:, 2:] - x[:, 2:]    # (V_x ^ (t+1), V_y ^ (t+1), a_x, a_y)

                # fully connected graph
                edge_index = torch.tensor([[i, j] for i in range(trajectory.shape[1]) for j in range(trajectory.shape[1]) if i != j], dtype=torch.long).t().contiguous()
    
                if self.post_transform is not None:
                    data = self.post_transform(data)
                
                data = Data(x=x, y=y, edge_index=edge_index)
                data_list.append(data)
        data, slices = self.collate(data_list)
        torch.save((data, slices), self.processed_data_path+self.processed_file_name)

    def __getitem__(self, idx):
        return self.get(idx)
    
    def __repr__(self):
        return f'{self.__class__.__name__}({len(self)})'

# %%
train_dataset = AR_Boids_Dataset(raw_data_path="../../data/boids/raw/", processed_data_path="../../data/boids/processed/", root="../../data/boids/", solution_idx_range=(0, 15), timesteps=1000, processed_file_name="AR1_Boids.pt")
validation_dataset = AR_Boids_Dataset(raw_data_path="../../data/boids/raw/", processed_data_path="../../data/boids/processed/", root="../../data/boids/", solution_idx_range=(16, 25), timesteps=1000, processed_file_name="AR1_VAL_Boids.pt")

print(train_dataset)
print(validation_dataset)


data_0 = train_dataset[0]
print(data_0)
print(data_0.keys)
print("Pos x, Pos y, Vel x, Vel y")
print(data_0.x[0,:])
print(data_0.y[0,:])  # delta pos x, delta pos y, acc x, acc y
# Out:
# AR_Boids_Dataset(14985)
# AR_Boids_Dataset(8991)
# Data(x=[25, 4], edge_index=[2, 600], y=[25, 4])
# <bound method BaseData.keys of Data(x=[25, 4], edge_index=[2, 600], y=[25, 4])>
# Pos x, Pos y, Vel x, Vel y
# tensor([719., 745.,   5.,  -3.])
# tensor([ 5., -3.,  0.,  0.])

# %% [markdown]
# ## Autoregressive Models
# In general, when dealing with simulations spanning multiple timesteps, we can define the learning problem as follows.
#
# Let $X^{0:T-1}$ denote the states spanning across timesteps $t=0$ through $t=T-1$. Given the initial state $X^0$, our goal is to accurately predict the future states $X^{1:T-1}$. In the probabilistic case, we want to learn a model with parameters $\theta$ for the probability distribution $P_\theta(X^{1:T-1}|X^0)$.*
#
# In some systems, such as in the Boids setting, the next state X^{t+1} is only dependent on the current state X^t. Such systems are memoryless, and are often said to be _Markovian_. The Markov property allows us to rewrite the learning task to $P_\theta(X^{1:T-1}|X^0) = \prod_{t=0}^{T-2} P_\theta(X^{t+1} | X^t)$
#
# Here, $P_\theta(X^{t+1} | X^t)$ is the _Autoregressive model_ - literally meaning it is used to autoregressively construct the full trajectory of the system. Note that this model is autoregressive in time; not space.
#
# *: In this practical, we will not be building a probabilistic model. So instead of parameterizing a distribution, we learn a function $f_\theta: X^t \rarr X^{t+1}$.

# %% [markdown]
# ### Autoregressive set model
#
# Below, we create the simplest AR model for the Boids system; a fully connected GNN (essentially a set model).
#
# Given a fully connected graph $X^t$, representing the Boids system at time $t$; it learns to predict the next state of the system $X^{t+1}$.
#
# Note here that we use all features from the dataset as node features. This causes the model to not be equivariant to some group actions, that are relevant in the Boids setting.
#
# ---
#
# Tick the equivariance(s) of this model:
#
# - <input
#       type="checkbox"
#       id="eq0"
#       name="perm"
#       value="perm" />
#     <label for="eq1">Permutational Equivariance</label>
#
# - <input
#       type="checkbox"
#       id="eq1"
#       name="space"
#       value="space" />
#     <label for="eq1">Space Translation Equivariance</label>
#
# - <input
#       type="checkbox"
#       id="eq2"
#       name="time"
#       value="time" />
#     <label for="eq2">Time Translation Equivariance</label>
#
# - <input
#       type="checkbox"
#       id="eq3"
#       name="rot"
#       value="rot" />
#     <label for="eq3">Rotation/Reflection Equivariance</label>

# %%
class AR_Set_Model(torch.nn.Module):
    def __init__(self, node_dim=4, emb_dim=16, out_dim=4):
        super(AR_Set_Model, self).__init__()
        self.node_embedding = torch.nn.Linear(node_dim, emb_dim)
        self.conv1 = torch_geometric.nn.GCNConv(emb_dim, emb_dim)
        self.conv2 = torch_geometric.nn.GCNConv(emb_dim, out_dim)
    
    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.node_embedding(x)
        x = torch.nn.functional.relu(x)
        x = self.conv1(x, edge_index)
        x = torch.nn.functional.relu(x)
        x = self.conv2(x, edge_index)
        return x

# %%
class Trainer:
    def __init__(self, model, train_dataset, validation_dataset, batch_size=1, lr=0.0001, epochs=100, loss_fn=torch.nn.MSELoss(), model_name= "01-AR-Set-Model.pt"):
        """
        Simple Trainer class to train a PyTorch (geometric) model on a dataset.

        Args:
            model: PyTorch model to train
            train_dataset: PyTorch dataset to train on
            validation_dataset: PyTorch dataset to validate on
            batch_size: Batch size for training
            lr: Learning rate
            epochs: Number of epochs to train for
            loss_fn: Loss function to use
        """
        self.model = model
        self.train_dataset = train_dataset
        self.validation_dataset = validation_dataset
        self.batch_size = batch_size
        self.lr = lr
        self.epochs = epochs
        self.loss_fn = loss_fn
        self.model_name = model_name

        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        print("Using device:", self.device)
        self.model.to(self.device)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=self.lr)

        self.train_loader = self.make_data_loader(self.train_dataset)
        self.validation_loader = self.make_data_loader(self.validation_dataset, shuffle=False)

    def make_data_loader(self, dataset, shuffle=True):
        return DataLoader(dataset, batch_size=self.batch_size, shuffle=shuffle)

    def train_loop(self):
        """
        Train loop for the model
        """
        best_model_loss = np.inf
        for epoch in range(self.epochs):
            # Train the model
            self.model.train()
            mean_train_loss = 0
            for i, data in enumerate(self.train_loader):
                data = self.train_dataset[i].to(self.device)
                self.optimizer.zero_grad()
                out = self.model(data)
                loss = self.loss_fn(out, data.y)
                loss.backward()
                self.optimizer.step()
                mean_train_loss += loss.item()
            mean_train_loss /= i + 1
            
            # Validate the model
            self.model.eval()
            mean_val_loss = 0
            with torch.no_grad():
                for i, data in enumerate(self.validation_loader):
                    data = self.validation_dataset[i].to(self.device)
                    out = self.model(data)
                    loss = self.loss_fn(out, data.y)
                    mean_val_loss += loss.item()
                mean_val_loss /= i + 1

            if mean_val_loss < best_model_loss:
                best_model_loss = mean_val_loss
                torch.save(self.model.state_dict(), f"../../models/{self.model_name}")
            
            print(f"Epoch {epoch}, Mean Train Loss: {mean_train_loss}, Mean Validation Loss: {mean_val_loss}")

# %%
model = AR_Set_Model(emb_dim=64)
trainer = Trainer(model, train_dataset, validation_dataset, batch_size=8, loss_fn=torch.nn.MSELoss(), epochs=100, model_name="01-AR-Set-Model.pt")
trainer.train_loop()
# Out:
# Using device: cuda
# C:\Users\nasso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch_geometric\deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 0, Mean Train Loss: 627.9818120399262, Mean Validation Loss: 102.65119802962428
# Epoch 1, Mean Train Loss: 12.978555757160564, Mean Validation Loss: 57.138895753442654
# Epoch 2, Mean Train Loss: 7.765931757866095, Mean Validation Loss: 41.12525978580927
# Epoch 3, Mean Train Loss: 5.998473962169246, Mean Validation Loss: 48.88214194190789
# Epoch 4, Mean Train Loss: 5.160537443502154, Mean Validation Loss: 37.30369200668267
# Epoch 5, Mean Train Loss: 4.60944314255666, Mean Validation Loss: 33.25689452435433
# Epoch 6, Mean Train Loss: 4.33021364339965, Mean Validation Loss: 27.396006832776703
# Epoch 7, Mean Train Loss: 4.017736073108007, Mean Validation Loss: 23.111041754351486
# Epoch 8, Mean Train Loss: 3.8002745477642788, Mean Validation Loss: 19.857600335446406
# Epoch 9, Mean Train Loss: 3.631194641516289, Mean Validation Loss: 17.268184049789756
# Epoch 10, Mean Train Loss: 3.4941998674025587, Mean Validation Loss: 14.9856470132235
# Epoch 11, Mean Train Loss: 3.395589589086116, Mean Validation Loss: 13.655768030791652
# Epoch 12, Mean Train Loss: 3.3379546906371456, Mean Validation Loss: 12.849570302377295
# Epoch 13, Mean Train Loss: 3.331896939031975, Mean Validation Loss: 12.825205962146272
# Epoch 14, Mean Train Loss: 3.342886214102263, Mean Validation Loss: 12.699224889013031
# Epoch 15, Mean Train Loss: 3.3259439772612516, Mean Validation Loss: 12.656364529661483
# Epoch 16, Mean Train Loss: 3.3330352650055324, Mean Validation Loss: 12.868985090739793
# Epoch 17, Mean Train Loss: 3.3618771722147445, Mean Validation Loss: 13.448064431694078
# Epoch 18, Mean Train Loss: 3.3813959387490535, Mean Validation Loss: 13.681335562801955
# Epoch 19, Mean Train Loss: 3.3990394090562344, Mean Validation Loss: 14.094346894394151
# Epoch 20, Mean Train Loss: 3.4364660164282657, Mean Validation Loss: 14.727063013205864
# Epoch 21, Mean Train Loss: 3.486188153118229, Mean Validation Loss: 15.316026728809252
# Epoch 22, Mean Train Loss: 3.5484982935489975, Mean Validation Loss: 15.805193043986497
# Epoch 23, Mean Train Loss: 3.5661175677118235, Mean Validation Loss: 15.87149548254582
# Epoch 24, Mean Train Loss: 3.563495037712264, Mean Validation Loss: 15.799673497836078
# Epoch 25, Mean Train Loss: 3.548836810666485, Mean Validation Loss: 15.628155183919498
# Epoch 26, Mean Train Loss: 3.5307231659693192, Mean Validation Loss: 15.434317901531502
# Epoch 27, Mean Train Loss: 3.5121710342452035, Mean Validation Loss: 15.223006826580791
# Epoch 28, Mean Train Loss: 3.4910919232223354, Mean Validation Loss: 14.999561311088284
# Epoch 29, Mean Train Loss: 3.4715136119024805, Mean Validation Loss: 14.804345552558253
# Epoch 30, Mean Train Loss: 3.4491711039627164, Mean Validation Loss: 14.553099456474596
# Epoch 31, Mean Train Loss: 3.4298119807841623, Mean Validation Loss: 14.368660454864706
# Epoch 32, Mean Train Loss: 3.4107142441169627, Mean Validation Loss: 14.119641766204223
# Epoch 33, Mean Train Loss: 3.3862432971143237, Mean Validation Loss: 13.829839738903573
# Epoch 34, Mean Train Loss: 3.3606562382132372, Mean Validation Loss: 13.859357477614418
# Epoch 35, Mean Train Loss: 3.33747527103531, Mean Validation Loss: 13.59238487508609
# Epoch 36, Mean Train Loss: 3.3288101187951415, Mean Validation Loss: 13.251986798705104
# Epoch 37, Mean Train Loss: 3.314169496663802, Mean Validation Loss: 13.01874067628373
# Epoch 38, Mean Train Loss: 3.296755972961277, Mean Validation Loss: 12.691922079104987
# Epoch 39, Mean Train Loss: 3.277381202592865, Mean Validation Loss: 12.37854223429679
# Epoch 40, Mean Train Loss: 3.2568345174264985, Mean Validation Loss: 12.22549548323199
# Epoch 41, Mean Train Loss: 3.243053597622356, Mean Validation Loss: 12.07841535497752
# Epoch 42, Mean Train Loss: 3.236135866924587, Mean Validation Loss: 11.957488413697783
# Epoch 43, Mean Train Loss: 3.2319359717302887, Mean Validation Loss: 11.941606221407094
# Epoch 44, Mean Train Loss: 3.2289759826672886, Mean Validation Loss: 11.898679321192251
# Epoch 45, Mean Train Loss: 3.2285544763130742, Mean Validation Loss: 11.839318099663073
# Epoch 46, Mean Train Loss: 3.227866444718819, Mean Validation Loss: 11.845113611391158
# Epoch 47, Mean Train Loss: 3.2188067634794333, Mean Validation Loss: 11.652348469541419
# Epoch 48, Mean Train Loss: 3.2092628356166784, Mean Validation Loss: 11.644259923075525
# Epoch 49, Mean Train Loss: 3.201102381139532, Mean Validation Loss: 11.669524321254618
# Epoch 50, Mean Train Loss: 3.2015811285104463, Mean Validation Loss: 11.702850644331582
# Epoch 51, Mean Train Loss: 3.2084918219777143, Mean Validation Loss: 12.185734508511008
# Epoch 52, Mean Train Loss: 3.227177388771167, Mean Validation Loss: 11.99574119197611
# Epoch 53, Mean Train Loss: 3.2702027613061415, Mean Validation Loss: 12.937943789965322
# Epoch 54, Mean Train Loss: 3.258239279694565, Mean Validation Loss: 11.683846766674826
# Epoch 55, Mean Train Loss: 3.261641551897097, Mean Validation Loss: 12.050012055190674
# Epoch 56, Mean Train Loss: 3.2921106858617537, Mean Validation Loss: 12.655892081910334
# Epoch 57, Mean Train Loss: 3.3059550685419223, Mean Validation Loss: 12.283213415213812
# Epoch 58, Mean Train Loss: 3.318363322495014, Mean Validation Loss: 13.176800001336334
# Epoch 59, Mean Train Loss: 3.32631383054217, Mean Validation Loss: 13.057634871025119
# Epoch 60, Mean Train Loss: 3.3730855984479047, Mean Validation Loss: 13.598325614300776
# Epoch 61, Mean Train Loss: 3.3449812164232813, Mean Validation Loss: 13.99918137823803
# Epoch 62, Mean Train Loss: 3.3324340065405194, Mean Validation Loss: 13.490627064836524
# Epoch 63, Mean Train Loss: 3.2574934706418066, Mean Validation Loss: 12.46489658487342
# Epoch 64, Mean Train Loss: 3.222654679848813, Mean Validation Loss: 11.569969097207087
# Epoch 65, Mean Train Loss: 3.2230094705300094, Mean Validation Loss: 12.496666079849827
# Epoch 66, Mean Train Loss: 3.2255927015611086, Mean Validation Loss: 12.447127964914854
# Epoch 67, Mean Train Loss: 3.216429740651941, Mean Validation Loss: 12.264781734079309
# Epoch 68, Mean Train Loss: 3.2090724373462045, Mean Validation Loss: 12.097560005323864
# Epoch 69, Mean Train Loss: 3.20456310109028, Mean Validation Loss: 11.96700928451117
# Epoch 70, Mean Train Loss: 3.1965112196718124, Mean Validation Loss: 11.761756744537625
# Epoch 71, Mean Train Loss: 3.189277323407409, Mean Validation Loss: 11.608675585616835
# Epoch 72, Mean Train Loss: 3.1857375552548612, Mean Validation Loss: 11.436498398666178
# Epoch 73, Mean Train Loss: 3.1706206086670976, Mean Validation Loss: 10.418281074729437
# Epoch 74, Mean Train Loss: 3.150062229947743, Mean Validation Loss: 10.028358781964037
# Epoch 75, Mean Train Loss: 3.100841732631058, Mean Validation Loss: 9.648008309828842
# Epoch 76, Mean Train Loss: 3.079190261435267, Mean Validation Loss: 9.611192140001753
# Epoch 77, Mean Train Loss: 3.07535920134217, Mean Validation Loss: 9.517871891932092
# Epoch 78, Mean Train Loss: 3.0740568219374285, Mean Validation Loss: 9.44046328880908
# Epoch 79, Mean Train Loss: 3.0708723437066903, Mean Validation Loss: 9.310968531738512
# Epoch 80, Mean Train Loss: 3.067064021719501, Mean Validation Loss: 9.18199307984363
# Epoch 81, Mean Train Loss: 3.0729600004633033, Mean Validation Loss: 9.098195906738457
# Epoch 82, Mean Train Loss: 3.0611338866501647, Mean Validation Loss: 8.993045309029407
# Epoch 83, Mean Train Loss: 3.137568139800781, Mean Validation Loss: 9.08453211291815
# Epoch 84, Mean Train Loss: 3.1648071072219977, Mean Validation Loss: 9.081599828502693
# Epoch 85, Mean Train Loss: 3.1095577827508096, Mean Validation Loss: 8.334968840980359
# Epoch 86, Mean Train Loss: 3.054899588537547, Mean Validation Loss: 7.93949998964291
# Epoch 87, Mean Train Loss: 3.0397107124455904, Mean Validation Loss: 7.772585960763539
# Epoch 88, Mean Train Loss: 3.008684719048015, Mean Validation Loss: 7.6723993402024195
# Epoch 89, Mean Train Loss: 3.0095752085267193, Mean Validation Loss: 7.602148948348428
# Epoch 90, Mean Train Loss: 3.0171151005578944, Mean Validation Loss: 7.587120449553614
# Epoch 91, Mean Train Loss: 3.0309922638514815, Mean Validation Loss: 7.4674431492150735
# Epoch 92, Mean Train Loss: 3.0306421859151085, Mean Validation Loss: 7.624840481835396
# Epoch 93, Mean Train Loss: 3.0457003151294835, Mean Validation Loss: 7.616303761092447
# Epoch 94, Mean Train Loss: 3.045712980241363, Mean Validation Loss: 7.665045454792963
# Epoch 95, Mean Train Loss: 3.184431188098899, Mean Validation Loss: 9.340232465485856
# Epoch 96, Mean Train Loss: 3.2459542433717834, Mean Validation Loss: 9.954966666968083
# Epoch 97, Mean Train Loss: 3.3211652920071733, Mean Validation Loss: 10.153466356087241
# Epoch 98, Mean Train Loss: 3.363820726198114, Mean Validation Loss: 10.405908223039214
# Epoch 99, Mean Train Loss: 3.3875877894123034, Mean Validation Loss: 10.924316034503844

# %% [markdown]
# ### Q1: Implementing rollout code
#
# We have a working model now to predict $\hat{X}^{t+1}$ given $X^t$. However, we of course want to be able to generate trajectories longer than one step (ie for i steps: $\hat{X}^{t+1:t+i}$), given $X^t$.
#
# We sometimes call this a `rollout` - essentially a multi-step prediction.
#
# Q1: Complete the method below, which generates a rollout of `timesteps` steps, for a given model `model`, and dataset `dataset` *.
#
# HINT: What should happen if the position $x_i, y_i$ of boid $i$ are predicted to move $dx_i, dy_i$, such that $x_i + dx_i > \text{width}$ or $y_i + dy_i > \text{height}$?
#
# *: If you check the cell below the next cell, we already made a dataset for you that only contains initial positions :)

# %%
def compute_ar_set_model_rollouts(model, dataset, timesteps=1000, device='cuda', mode="residual", width = 1000, height = 1000):
    """
    Predict the rollouts of the model on the dataset starting from the idx

    Args:
        model: PyTorch model
        dataset: PyTorch dataset
        timesteps: Number of timesteps to predict
        device: Device to run the model on
        mode: "residual" or "direct"
        - In the solution above, we used the "residual" mode, where the model predicts the change in position and change in velocity
        - In the "direct" mode, the model predicts the position and velocity directly (if you do not intend to use this mode, you can ignore this argument)
        width: Width of the PBC box
        height: Height of the PBC box
    Returns:
        rollouts: Rollouts of the model on the dataset
        - Should be a torch tensor of shape (Batch, Timesteps, Boids, Node_dim)
    """
    rollouts = torch.empty((len(dataset), timesteps, dataset[0].x.shape[0], dataset[0].x.shape[1]), device=device)
    print(rollouts.shape)

    model.to(device)
    model.eval()
    with torch.no_grad():
        for i in range(len(dataset)):
            data = dataset[i].to(device)
            # Initialize the rollout with the initial state
            rollouts[i, 0] = data.x
            current_state = data.x.clone()
            for t in range(1, timesteps):
                data.x = current_state
                out = model(data)
                if mode == "residual":
                    current_state[:, :2] += out[:, :2]
                    current_state[:, 2:] += out[:, 2:]
                elif mode == "direct":
                    current_state = out
                
                # Apply periodic boundary conditions (PBC)
                current_state[:, 0] = current_state[:, 0] % width   # PBC for x position
                current_state[:, 1] = current_state[:, 1] % height  # PBC for y position
                
                rollouts[i, t] = current_state
                if t % 100 == 0:
                    print(f"Predicted timestep {t} for trajectory {i}")
    
    return rollouts

# %%
def keep_01(data):
    return data[0:2, :, :]

initial_states_validation_dataset = AR_Boids_Dataset(
    raw_data_path="../../data/boids/raw/", 
    processed_data_path="../../data/boids/processed/", 
    root="../../data/boids/", 
    solution_idx_range=(16, 25), 
    timesteps=2, 
    processed_file_name="AR1_VAL_init.pt",
    transform=keep_01
    )

ar_set_model = AR_Set_Model(emb_dim=64)
ar_set_model.load_state_dict(torch.load("../../models/01-AR-Set-Model.pt"))
device = 'cuda' if torch.cuda.is_available() else 'cpu'
ar_set_model.to(device)
ar_set_model.eval()

ar_set_model_rollout = compute_ar_set_model_rollouts(ar_set_model, initial_states_validation_dataset, timesteps=1000, device=device)
# Out:
# torch.Size([9, 1000, 25, 4])
# Predicted timestep 100 for trajectory 0
# Predicted timestep 200 for trajectory 0
# Predicted timestep 300 for trajectory 0
# Predicted timestep 400 for trajectory 0
# Predicted timestep 500 for trajectory 0
# Predicted timestep 600 for trajectory 0
# Predicted timestep 700 for trajectory 0
# Predicted timestep 800 for trajectory 0
# Predicted timestep 900 for trajectory 0
# Predicted timestep 100 for trajectory 1
# Predicted timestep 200 for trajectory 1
# Predicted timestep 300 for trajectory 1
# Predicted timestep 400 for trajectory 1
# Predicted timestep 500 for trajectory 1
# Predicted timestep 600 for trajectory 1
# Predicted timestep 700 for trajectory 1
# Predicted timestep 800 for trajectory 1
# Predicted timestep 900 for trajectory 1
# Predicted timestep 100 for trajectory 2
# Predicted timestep 200 for trajectory 2
# Predicted timestep 300 for trajectory 2
# Predicted timestep 400 for trajectory 2
# Predicted timestep 500 for trajectory 2
# Predicted timestep 600 for trajectory 2
# Predicted timestep 700 for trajectory 2
# Predicted timestep 800 for trajectory 2
# Predicted timestep 900 for trajectory 2
# Predicted timestep 100 for trajectory 3
# Predicted timestep 200 for trajectory 3
# Predicted timestep 300 for trajectory 3
# Predicted timestep 400 for trajectory 3
# Predicted timestep 500 for trajectory 3
# Predicted timestep 600 for trajectory 3
# Predicted timestep 700 for trajectory 3
# Predicted timestep 800 for trajectory 3
# Predicted timestep 900 for trajectory 3
# Predicted timestep 100 for trajectory 4
# Predicted timestep 200 for trajectory 4
# Predicted timestep 300 for trajectory 4
# Predicted timestep 400 for trajectory 4
# Predicted timestep 500 for trajectory 4
# Predicted timestep 600 for trajectory 4
# Predicted timestep 700 for trajectory 4
# Predicted timestep 800 for trajectory 4
# Predicted timestep 900 for trajectory 4
# Predicted timestep 100 for trajectory 5
# Predicted timestep 200 for trajectory 5
# Predicted timestep 300 for trajectory 5
# Predicted timestep 400 for trajectory 5
# Predicted timestep 500 for trajectory 5
# Predicted timestep 600 for trajectory 5
# Predicted timestep 700 for trajectory 5
# Predicted timestep 800 for trajectory 5
# Predicted timestep 900 for trajectory 5
# Predicted timestep 100 for trajectory 6
# Predicted timestep 200 for trajectory 6
# Predicted timestep 300 for trajectory 6
# Predicted timestep 400 for trajectory 6
# Predicted timestep 500 for trajectory 6
# Predicted timestep 600 for trajectory 6
# Predicted timestep 700 for trajectory 6
# Predicted timestep 800 for trajectory 6
# Predicted timestep 900 for trajectory 6
# Predicted timestep 100 for trajectory 7
# Predicted timestep 200 for trajectory 7
# Predicted timestep 300 for trajectory 7
# Predicted timestep 400 for trajectory 7
# Predicted timestep 500 for trajectory 7
# Predicted timestep 600 for trajectory 7
# Predicted timestep 700 for trajectory 7
# Predicted timestep 800 for trajectory 7
# Predicted timestep 900 for trajectory 7
# Predicted timestep 100 for trajectory 8
# Predicted timestep 200 for trajectory 8
# Predicted timestep 300 for trajectory 8
# Predicted timestep 400 for trajectory 8
# Predicted timestep 500 for trajectory 8
# Predicted timestep 600 for trajectory 8
# Predicted timestep 700 for trajectory 8
# Predicted timestep 800 for trajectory 8
# Predicted timestep 900 for trajectory 8

# %%
print(len(initial_states_validation_dataset))
# Out:
# 9

# %% [markdown]
# We'll evaluate these rollouts later.

# %% [markdown]
# ### Quick recap on equivariances
#
# <img src="figures/boids-translational-equivariance.png" alt="drawing" width="250" style="background-color: white; padding: 50px;"/>
# <img src="figures/boids-rotational-equivariance.png" alt="drawing" width="250" style="background-color: white; padding: 50px;"/>
#
# The figures above show the equivariances of the Boids system. The system is equivariant to all E(n) transformations; translation,
# rotation and reflection.*
#
# Formally, we say a function $f: X \rarr Y$ is _equivariant_ to a group action or transformation $T: X \rarr X$ if there is an equivalent transformation $S: Y \rarr Y$ on the output space of the function such that
#
# $f(T(x)) = S(f(x))$ for each $x \in X$
#
# We won't go into the formal definitions of each equivariance, but if you're interested you can check out the [E(n) Equivariant Graph Neural Networks](https://arxiv.org/pdf/2102.09844) paper [3], the equivariant model is based on.
#
# *: Excluding time translation equivariance, which states that there is no dependence on the time of the system, only the state.
#
# *: Also excluding permutational equivariance; the order of the nodes does not matter.
#
# ## Towards Equivariant AR-GNNs
# The above model is **not** equivariant to translations in space! This is because we use absolute coordinates as _node features_, which creates a dependence on the absolute coordinate system. Instead, if we do not use the absolute positions as node features - and include the PBC distance as _edge features_ - the predictions will be space translation equivariant.
#
# Let's implement this!

# %% [markdown]
# Before, we were not using the fact that boids only affect eachother within a certain radius, since we used a fully connected graph without edge weights.
#
# Before blindly jumping into the new dataset code, let's investigate this behavior.

# %%
# Plot timesteps 0, 250, 500, 750, 999 for the first trajectory
trajectory = trajectories[0]
fig, axs = plt.subplots(1, 5, figsize=(20, 4))
fig.suptitle("Boids with radius of effect")
radius = 40

for i, t in enumerate([0, 250, 500, 750, 999]):
    axs[i].set_title(f"Timestep {t}")
    # Plot dots for the boids
    axs[i].scatter(trajectory[t, :, 0], trajectory[t, :, 1])
    # Draw a red circle around each boid to indicate the radius
    for j in range(trajectory.shape[1]):
        circle = plt.Circle((trajectory[t, j, 0], trajectory[t, j, 1]), radius, color='r', fill=False)
        axs[i].add_artist(circle)
    # plot the boid velocities as arrows
    for j in range(trajectory.shape[1]):
        # NOTE: The arrows are made larger for effect
        axs[i].arrow(trajectory[t, j, 0], trajectory[t, j, 1], trajectory[t, j, 2]*5, trajectory[t, j, 3]*5)
plt.show()

# %% [markdown]
# Above, we show the boids with their radius of effect. As expected, boids who are farther than `radius=40` units away from eachother, are shown to not affect eachother.
#
# ## Question 2: Implement your own model
#
# As discussed above, the Boids system is equivariant to
# - Permutation
# - Translation
# - Rotation/Reflection
#
# Your next task is to build a model that is at least* equivariant to permutation and translation. Make sure your model adheres to the PBC, either via the loss function or position updates.
#
# For this you will have to code up:
#
# 1. The `InMemoryDataset` used when training your model.
# 2. The Permutation/Translation Equivariant model `TranslationalEquivariantModel`
# 3. Possibly a new rollout method `model2_rollouts`
#     - HINT: Depending on your design choices, you may need to store the initial coordinates of your nodes.
#
# *: You are of course welcome to build a model that is E(n) equivariant, but this is next week's material `:^)`

# %%
from tqdm import trange

class Equivariant_Boids_Dataset2(InMemoryDataset):
    def __init__(self, raw_data_path, processed_data_path, root=None,
                 transform=None, pre_transform=None, post_transform=None,
                 solution_idx_range=(0, 25), timesteps=1000,
                 processed_file_name="AR1_Boids_Equivariant.pt", L=1000):
        self.raw_data_path = raw_data_path
        self.processed_data_path = processed_data_path
        self.solution_idx_range = solution_idx_range
        self.timesteps = timesteps
        self.processed_file_name = processed_file_name
        self.pre_transform = pre_transform
        self.transform = transform
        self.post_transform = post_transform
        self.L = L
        super(Equivariant_Boids_Dataset2, self).__init__(root, transform, pre_transform)
        self.data, self.slices = torch.load(self.processed_paths[0], weights_only=False) #TODO check this

    @property
    def processed_file_names(self):
        return [self.processed_file_name]

    @property
    def raw_file_names(self):
        return [pfn for pfn in os.listdir(self.raw_data_path)
                if (self.solution_idx_range[0] <= int(pfn.split("_")[-1][:-4]) < self.solution_idx_range[1])]

    def download(self):
        pass

    def __len__(self):
        return (self.timesteps - 1) * (self.solution_idx_range[1] - self.solution_idx_range[0])

    def process(self):
        data_list = []
        all_init_positions = []   
        vmax = 0.0
        for raw_path in self.raw_file_names:
            trajectory = np.load(os.path.join(self.raw_data_path, raw_path))  
            vels = trajectory[:, :, 2:]  
            vmax = max(vmax, np.abs(vels).max())
        if vmax == 0:
            vmax = 1.0

        print(f"[Normalization] Using L={self.L}, vmax={vmax:.4f}")

        for raw_path in self.raw_file_names:
            trajectory = np.load(os.path.join(self.raw_data_path, raw_path))

            init_pos = torch.tensor(trajectory[0, :, :2], dtype=torch.float)  
            all_init_positions.append(init_pos)

            for t in range(trajectory.shape[0] - 1):
                pos_t = torch.tensor(trajectory[t, :, :2], dtype=torch.float) / self.L
                vel_t = torch.tensor(trajectory[t, :, 2:], dtype=torch.float) / vmax
                pos_next = torch.tensor(trajectory[t+1, :, :2], dtype=torch.float) / self.L
                vel_next = torch.tensor(trajectory[t+1, :, 2:], dtype=torch.float) / vmax

                x = torch.cat([pos_t, vel_t], dim=-1)   
                y = torch.cat([pos_next, vel_next], dim=-1)   

                N = pos_t.shape[0]
                edge_index = torch.combinations(torch.arange(N), r=2, with_replacement=False).T
                edge_index = torch.cat([edge_index, edge_index.flip(0)], dim=1)
                senders, receivers = edge_index

                rel_disp = pos_t[receivers] - pos_t[senders]
                rel_disp = rel_disp - torch.round(rel_disp)
                edge_attr = rel_disp

                data = Data(x=x, edge_index=edge_index, edge_attr=edge_attr, y=y)
                data_list.append(data)

        data, slices = self.collate(data_list)
        torch.save((data, slices), self.processed_paths[0])

        all_init_positions = torch.stack(all_init_positions)   
        torch.save(all_init_positions, os.path.join(self.processed_data_path,
                                                    "positions_" + self.processed_file_name))
        print(f"Saved initial positions: {all_init_positions.shape}")
        
    def __getitem__(self, idx):
        return self.get(idx)
    
    def __repr__(self):
        return f'{self.__class__.__name__}({len(self)})'

# %%
equivariant_train_dataset = Equivariant_Boids_Dataset2(
    raw_data_path="../../data/boids/raw/", 
    processed_data_path="../../data/boids/processed/", 
    root="../../data/boids/", 
    solution_idx_range=(0, 15), 
    timesteps=1000, 
    processed_file_name="AR1_Boids_Equivariant16.pt"
    )

equivariant_validation_dataset = Equivariant_Boids_Dataset2(
    raw_data_path="../../data/boids/raw/", 
    processed_data_path="../../data/boids/processed/", 
    root="../../data/boids/", 
    solution_idx_range=(16, 25), 
    timesteps=1000, 
    processed_file_name="AR1_VAL_Boids_Equivariant16.pt"
    )
# Out:
# Processing...
# [Normalization] Using L=1000, vmax=6.0000
# Saved initial positions: torch.Size([15, 25, 2])
# [Normalization] Using L=1000, vmax=6.0000
# Done!
# Processing...
# Saved initial positions: torch.Size([9, 25, 2])
# Done!

# %%
print(len(equivariant_train_dataset))
print(len(equivariant_validation_dataset))
# Out:
# 14985
# 8991

# %%
print(equivariant_train_dataset[0])
# Out:
# Data(x=[25, 4], edge_index=[2, 600], edge_attr=[600, 2], y=[25, 4])

# %%
init_positions = torch.load("../../data/boids/processed/positions_AR1_Boids_Equivariant.pt")
print(init_positions.shape)
print(len(init_positions))
init_val_positions = torch.load("../../data/boids/processed/positions_AR1_VAL_Boids_Equivariant.pt")
print(init_val_positions.shape)
print(len(init_val_positions))
# Out:
# torch.Size([15, 25, 2])
# 15
# torch.Size([9, 25, 2])
# 9

# %%
class TranslationalEquivariantModel(torch.nn.Module):
    def __init__(self, hidden_dim=16, out_dim=4):
        super().__init__()
        self.edge_mlp = torch.nn.Sequential(
            torch.nn.Linear(2, hidden_dim),  # input: relative position r_ij
            torch.nn.ReLU(),
            torch.nn.Linear(hidden_dim, hidden_dim)
        )
        self.node_mlp = torch.nn.Sequential(
            torch.nn.Linear(hidden_dim + 2, hidden_dim),  # aggregated messages + node velocity
            torch.nn.ReLU(),
            torch.nn.Linear(hidden_dim, out_dim)  # output: dx, dv
        )
    
    def forward(self, data):
        x, v = data.x[:, :2], data.x[:, 2:]  # pos, vel
        src, dst = data.edge_index

        r_ij = x[dst] - x[src]  # translation equivariant

        m_ij = self.edge_mlp(r_ij)

        # aggregate messages (permutation equivariant)
        m_i = scatter_mean(m_ij, src, dim=0, dim_size=x.size(0))

        # combine with node features (velocities)
        node_input = torch.cat([m_i, v], dim=-1)
        out = self.node_mlp(node_input)
        return out

# %%
translational_equivariant_model = TranslationalEquivariantModel()
trainer = Trainer(translational_equivariant_model, equivariant_train_dataset, equivariant_validation_dataset, batch_size=8, loss_fn=torch.nn.MSELoss(), epochs=100, model_name="02-Translational-Equivariant-Model.pt")
trainer.train_loop()
# Out:
# Using device: cuda
# C:\Users\nasso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch_geometric\deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 0, Mean Train Loss: 11.189041388015728, Mean Validation Loss: 4.403342629795295
# Epoch 1, Mean Train Loss: 2.6066494213344575, Mean Validation Loss: 3.705276345739594
# Epoch 2, Mean Train Loss: 1.894817067955626, Mean Validation Loss: 2.385702857245108
# Epoch 3, Mean Train Loss: 0.8212481336404599, Mean Validation Loss: 0.5459637964610425
# Epoch 4, Mean Train Loss: 0.10860409307280168, Mean Validation Loss: 0.0524719635344783
# Epoch 5, Mean Train Loss: 0.010343353744612154, Mean Validation Loss: 0.012759663801841795
# Epoch 6, Mean Train Loss: 0.005757915917208425, Mean Validation Loss: 0.011236041482104253
# Epoch 7, Mean Train Loss: 0.005395218030206742, Mean Validation Loss: 0.010800137823185936
# Epoch 8, Mean Train Loss: 0.005241207173077061, Mean Validation Loss: 0.010599844158784249
# Epoch 9, Mean Train Loss: 0.0051529458497720036, Mean Validation Loss: 0.010457076361784976
# Epoch 10, Mean Train Loss: 0.005101945349710183, Mean Validation Loss: 0.010371438397137318
# Epoch 11, Mean Train Loss: 0.00506777335279265, Mean Validation Loss: 0.0103159037063405
# Epoch 12, Mean Train Loss: 0.005045099157260547, Mean Validation Loss: 0.010279866364642103
# Epoch 13, Mean Train Loss: 0.00502892060128533, Mean Validation Loss: 0.010253391649909085
# Epoch 14, Mean Train Loss: 0.005016454162209561, Mean Validation Loss: 0.010234817922998962
# Epoch 15, Mean Train Loss: 0.005008444584387671, Mean Validation Loss: 0.010220422728969081
# Epoch 16, Mean Train Loss: 0.005001227246751614, Mean Validation Loss: 0.010209703284453846
# Epoch 17, Mean Train Loss: 0.004995458214968119, Mean Validation Loss: 0.010199739542614149
# Epoch 18, Mean Train Loss: 0.004990629695950213, Mean Validation Loss: 0.01019074266460732
# Epoch 19, Mean Train Loss: 0.00498626210831691, Mean Validation Loss: 0.010184222414618659
# Epoch 20, Mean Train Loss: 0.004982317594444966, Mean Validation Loss: 0.010179224851563924
# Epoch 21, Mean Train Loss: 0.004978764001660144, Mean Validation Loss: 0.010175078381632495
# Epoch 22, Mean Train Loss: 0.004975477333372477, Mean Validation Loss: 0.010171659199980388
# Epoch 23, Mean Train Loss: 0.004972414429984336, Mean Validation Loss: 0.010169132599324728
# Epoch 24, Mean Train Loss: 0.004969514745158284, Mean Validation Loss: 0.010164862514164786
# Epoch 25, Mean Train Loss: 0.004966716761921613, Mean Validation Loss: 0.010161496997241885
# Epoch 26, Mean Train Loss: 0.004964023940256321, Mean Validation Loss: 0.010158408398393546
# Epoch 27, Mean Train Loss: 0.004961435267081459, Mean Validation Loss: 0.01015556446145314
# Epoch 28, Mean Train Loss: 0.004958896138912598, Mean Validation Loss: 0.01015313330918079
# Epoch 29, Mean Train Loss: 0.004956472696259435, Mean Validation Loss: 0.010151059646371923
# Epoch 30, Mean Train Loss: 0.004954135769034847, Mean Validation Loss: 0.010149099202763384
# Epoch 31, Mean Train Loss: 0.004951802490669984, Mean Validation Loss: 0.010147412223967919
# Epoch 32, Mean Train Loss: 0.0049495451612873755, Mean Validation Loss: 0.010146031379903407
# Epoch 33, Mean Train Loss: 0.004947339744634795, Mean Validation Loss: 0.01014499432092283
# Epoch 34, Mean Train Loss: 0.004945175034655638, Mean Validation Loss: 0.010143869756649949
# Epoch 35, Mean Train Loss: 0.004943079230539536, Mean Validation Loss: 0.010142615695699813
# Epoch 36, Mean Train Loss: 0.004941054235401967, Mean Validation Loss: 0.010141567997843813
# Epoch 37, Mean Train Loss: 0.004939052352279663, Mean Validation Loss: 0.01014051975142078
# Epoch 38, Mean Train Loss: 0.004937164334184176, Mean Validation Loss: 0.010140188670430962
# Epoch 39, Mean Train Loss: 0.0049353233594316695, Mean Validation Loss: 0.010141029621750503
# Epoch 40, Mean Train Loss: 0.004933367092799376, Mean Validation Loss: 0.010146070121896233
# Epoch 41, Mean Train Loss: 0.004931572538918662, Mean Validation Loss: 0.010152475034195236
# Epoch 42, Mean Train Loss: 0.004929935554778461, Mean Validation Loss: 0.0101532048064204
# Epoch 43, Mean Train Loss: 0.004928272843403757, Mean Validation Loss: 0.010153470946903376
# Epoch 44, Mean Train Loss: 0.0049265852207856205, Mean Validation Loss: 0.010154034815801126
# Epoch 45, Mean Train Loss: 0.004924972783883141, Mean Validation Loss: 0.010154632432041594
# Epoch 46, Mean Train Loss: 0.004923318948518277, Mean Validation Loss: 0.010156228351391721
# Epoch 47, Mean Train Loss: 0.00492174788058977, Mean Validation Loss: 0.0101582801245307
# Epoch 48, Mean Train Loss: 0.0049202011729538786, Mean Validation Loss: 0.0101612507239847
# Epoch 49, Mean Train Loss: 0.004918718382933285, Mean Validation Loss: 0.01016891120375229
# Epoch 50, Mean Train Loss: 0.004917225645956085, Mean Validation Loss: 0.010174537889162023
# Epoch 51, Mean Train Loss: 0.004915701619338885, Mean Validation Loss: 0.010179027269935116
# Epoch 52, Mean Train Loss: 0.004914186656655563, Mean Validation Loss: 0.010182658933586783
# Epoch 53, Mean Train Loss: 0.004912601633380141, Mean Validation Loss: 0.010197538891810827
# Epoch 54, Mean Train Loss: 0.004911772965659949, Mean Validation Loss: 0.010201738961046158
# Epoch 55, Mean Train Loss: 0.004910538644382558, Mean Validation Loss: 0.010205501536629826
# Epoch 56, Mean Train Loss: 0.00490781532367435, Mean Validation Loss: 0.01019951596114449
# Epoch 57, Mean Train Loss: 0.004906092576285369, Mean Validation Loss: 0.010197465408979877
# Epoch 58, Mean Train Loss: 0.004904628438632739, Mean Validation Loss: 0.010197984441547889
# Epoch 59, Mean Train Loss: 0.004903323173585134, Mean Validation Loss: 0.010199213691054945
# Epoch 60, Mean Train Loss: 0.0049019548344030614, Mean Validation Loss: 0.010200738727896414
# Epoch 61, Mean Train Loss: 0.004900618746004114, Mean Validation Loss: 0.010202172055808045
# Epoch 62, Mean Train Loss: 0.004899384818815196, Mean Validation Loss: 0.010204062103250297
# Epoch 63, Mean Train Loss: 0.004898084584385275, Mean Validation Loss: 0.010206027386608146
# Epoch 64, Mean Train Loss: 0.004896843407815605, Mean Validation Loss: 0.01020612419485044
# Epoch 65, Mean Train Loss: 0.004895645099783895, Mean Validation Loss: 0.010208411272095834
# Epoch 66, Mean Train Loss: 0.004894522816139468, Mean Validation Loss: 0.010210296264412657
# Epoch 67, Mean Train Loss: 0.00489341472448733, Mean Validation Loss: 0.010211880188695514
# Epoch 68, Mean Train Loss: 0.00489234216628333, Mean Validation Loss: 0.010214068562360248
# Epoch 69, Mean Train Loss: 0.004891296106209894, Mean Validation Loss: 0.01021481104637662
# Epoch 70, Mean Train Loss: 0.004890252933959374, Mean Validation Loss: 0.010215025759548906
# Epoch 71, Mean Train Loss: 0.004889249783306001, Mean Validation Loss: 0.010215223929409406
# Epoch 72, Mean Train Loss: 0.004888266431486979, Mean Validation Loss: 0.010214890708082947
# Epoch 73, Mean Train Loss: 0.0048872823138374835, Mean Validation Loss: 0.010213401052934027
# Epoch 74, Mean Train Loss: 0.004886272661191435, Mean Validation Loss: 0.010213336380296457
# Epoch 75, Mean Train Loss: 0.004885348445246234, Mean Validation Loss: 0.010212513966795194
# Epoch 76, Mean Train Loss: 0.004884428775271182, Mean Validation Loss: 0.010212798871849754
# Epoch 77, Mean Train Loss: 0.004883562032225889, Mean Validation Loss: 0.01021127700837541
# Epoch 78, Mean Train Loss: 0.004882628976559347, Mean Validation Loss: 0.010210729566296373
# Epoch 79, Mean Train Loss: 0.004881992524318245, Mean Validation Loss: 0.010204330431029966
# Epoch 80, Mean Train Loss: 0.00488084913554286, Mean Validation Loss: 0.010211771313999928
# Epoch 81, Mean Train Loss: 0.004880480694449393, Mean Validation Loss: 0.010201543470046823
# Epoch 82, Mean Train Loss: 0.004879092451564783, Mean Validation Loss: 0.010210443364410892
# Epoch 83, Mean Train Loss: 0.004878779059737311, Mean Validation Loss: 0.010200107246006026
# Epoch 84, Mean Train Loss: 0.00487743520166643, Mean Validation Loss: 0.010208484088493125
# Epoch 85, Mean Train Loss: 0.004877124262399949, Mean Validation Loss: 0.01019811887273684
# Epoch 86, Mean Train Loss: 0.0048757990837827855, Mean Validation Loss: 0.010207195441281706
# Epoch 87, Mean Train Loss: 0.004875486055419114, Mean Validation Loss: 0.010196114065483123
# Epoch 88, Mean Train Loss: 0.004874148729800485, Mean Validation Loss: 0.010204859995945085
# Epoch 89, Mean Train Loss: 0.004873876491490459, Mean Validation Loss: 0.010193679265448622
# Epoch 90, Mean Train Loss: 0.004872590305108903, Mean Validation Loss: 0.010202655373790628
# Epoch 91, Mean Train Loss: 0.00487228116493851, Mean Validation Loss: 0.010190753557668287
# Epoch 92, Mean Train Loss: 0.004870927501017211, Mean Validation Loss: 0.010199777883541677
# Epoch 93, Mean Train Loss: 0.00487058291644467, Mean Validation Loss: 0.010187463077326958
# Epoch 94, Mean Train Loss: 0.004869240441753592, Mean Validation Loss: 0.010197620976080608
# Epoch 95, Mean Train Loss: 0.004868874459677412, Mean Validation Loss: 0.01018413973233384
# Epoch 96, Mean Train Loss: 0.004867530870366343, Mean Validation Loss: 0.010194784410909803
# Epoch 97, Mean Train Loss: 0.004867128812501545, Mean Validation Loss: 0.010181018210509428
# Epoch 98, Mean Train Loss: 0.004865726447985446, Mean Validation Loss: 0.010191771868261913
# Epoch 99, Mean Train Loss: 0.004865279262320156, Mean Validation Loss: 0.010178455545193059

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.data import Data

def scatter_add(src, index, dim=0, dim_size=None):
    out = torch.zeros((dim_size, src.size(-1)), device=src.device, dtype=src.dtype)
    return out.index_add(dim, index, src)
def mlp(channels, act=nn.SiLU, final_act=False, dropout=0.0):
    layers = []
    for i in range(len(channels) - 1):
        layers.append(nn.Linear(channels[i], channels[i+1]))
        if i < len(channels) - 2 or final_act:
            layers.append(act())
            if dropout > 0:
                layers.append(nn.Dropout(dropout))
    return nn.Sequential(*layers)

class EGNNLayer(nn.Module):
    """
    E(n)-Equivariant message passing layer.
    Inputs:
      x : (N, d) node coordinates (here d=2)
      h : (N, F) node features
      edge_index : (2, E) directed edges (i -> j)
      rel_disp : (E, d) relative displacement vectors (x_j - x_i) with periodic wrap (your edge_attr)
    """
    def __init__(self, in_features, hidden, coord_dim=2, edge_hidden=128, update_coords=True, dropout=0.0):
        super().__init__()
        self.coord_dim = coord_dim
        self.update_coords = update_coords

        self.phi_e = mlp([2 * in_features + 1, edge_hidden, edge_hidden], dropout=dropout)

        # phi_x: scalar to scale direction vector for coordinate update
        self.phi_x = mlp([edge_hidden, edge_hidden, 1], dropout=dropout)

        # phi_h: node update from (h_i, sum_j m_ij)
        self.phi_h = mlp([in_features + edge_hidden, hidden, hidden], dropout=dropout)

        # feature projection back to in_features (residual-style width keeping)
        self.h_proj = nn.Linear(hidden, in_features)

    def forward(self, x, h, edge_index, rel_disp):
        """
        x: (N, d), h: (N, F), edge_index: (2, E), rel_disp: (E, d)
        returns: x_out (N, d), h_out (N, F)
        """
        i, j = edge_index  
        # Use provided rel_disp = x_j - x_i (already wrapped), so ||x_j - x_i||^2 is invariant.
        r_ij = rel_disp  # (E, d)
        r2_ij = (r_ij ** 2).sum(dim=-1, keepdim=True)  # (E, 1)

        # Build edge inputs: [h_i, h_j, ||x_i - x_j||^2]
        e_in = torch.cat([h[i], h[j], r2_ij], dim=-1)  # (E, 2F+1)
        m_ij = self.phi_e(e_in)  # (E, H_e)

        # Coordinate update: x_j' = x_j + sum_i ( (x_j - x_i) * phi_x(m_ij) )
        if self.update_coords:
            w_ij = self.phi_x(m_ij)  # (E, 1)
            coord_msg = r_ij * w_ij  # (E, d)
            dx = scatter_add(coord_msg, j, dim=0, dim_size=x.size(0))  # sum over incoming to j
            x_out = x + dx
        else:
            x_out = x

        # Node (feature) update: h_j' = phi_h( h_j, sum_i m_ij )
        m_j = scatter_add(m_ij, j, dim=0, dim_size=h.size(0))  # (N, H_e)
        h_in = torch.cat([h, m_j], dim=-1)  # (N, F + H_e)
        h_hidden = self.phi_h(h_in)  # (N, H)
        h_delta = self.h_proj(h_hidden)  # (N, F)
        h_out = h + h_delta

        return x_out, h_out

class EGNN_Hybrid(nn.Module):
    """
    Hybrid EGNN:
      - Positions updated via equivariant EGNN layers.
      - Velocities predicted via velocity head.
      - Optional residual correction head for positions (uses only features h, so still E(n)-equivariant).
    """
    def __init__(self,
                 in_node_feats=2,
                 coord_dim=2,
                 hidden_dim=128,
                 n_layers=4,
                 edge_hidden=128,
                 dropout=0.0,
                 update_coords=True,
                 pos_residual=True):
        super().__init__()
        self.coord_dim = coord_dim
        self.in_node_feats = in_node_feats
        self.pos_residual = pos_residual

        # EGNN layers
        self.layers = nn.ModuleList([
            EGNNLayer(in_features=in_node_feats,
                      hidden=hidden_dim,
                      coord_dim=coord_dim,
                      edge_hidden=edge_hidden,
                      update_coords=update_coords,
                      dropout=dropout)
            for _ in range(n_layers)
        ])

        # Velocity head
        self.head_h = mlp([in_node_feats, hidden_dim, in_node_feats], dropout=dropout)
        self.head_vel = mlp([in_node_feats, hidden_dim, in_node_feats], dropout=dropout)

        # Small equivariant residual correction for positions
        if pos_residual:
            self.head_pos = mlp([in_node_feats, hidden_dim, coord_dim], dropout=dropout)

    def forward(self, data: Data):
        """
        data.x: (N, 4) = [pos(2), vel(2)]
        data.edge_index: (2, E)
        data.edge_attr: (E, 2) = relative displacement (x_j - x_i), optional
        """
        assert data.x.size(-1) == self.coord_dim + self.in_node_feats, \
            f"Expected state dim {self.coord_dim + self.in_node_feats}, got {data.x.size(-1)}"

        state = data.x
        x = state[:, :self.coord_dim]     # positions
        h = state[:, self.coord_dim:]     # velocities
        edge_index = data.edge_index
        rel_disp = getattr(data, 'edge_attr', None)

        if rel_disp is None:
            src, dst = edge_index
            rel_disp = x[dst] - x[src]

        # Pass through EGNN layers
        for layer in self.layers:
            x, h = layer(x, h, edge_index, rel_disp)

        # Velocity update
        vel_mid = self.head_h(h)
        vel_out = self.head_vel(vel_mid)

        # Position correction (optional, equivariant since only uses h)
        if self.pos_residual:
            pos_correction = self.head_pos(h)   # (N,2)
            x = x + pos_correction

        out = torch.cat([x, vel_out], dim=-1)  # (N,4)
        return out

# %%
model_egnn = EGNN_Hybrid(in_node_feats=2, coord_dim=2, hidden_dim=128, n_layers=4, edge_hidden=128, dropout=0.0, pos_residual=False)
trainer2 = Trainer(model_egnn, equivariant_train_dataset, equivariant_validation_dataset, batch_size=8, loss_fn=torch.nn.MSELoss(), epochs=100, model_name="02-Translational-Equivariant-Model.pt")
trainer2.train_loop()
# Out:
# Using device: cuda
# C:\Users\nasso\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch_geometric\deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 0, Mean Train Loss: 0.005903934618686071, Mean Validation Loss: 0.019293720023917844
# Epoch 1, Mean Train Loss: 0.002188744188111283, Mean Validation Loss: 0.017778694993726002
# Epoch 2, Mean Train Loss: 0.002092707384269809, Mean Validation Loss: 0.018137946869685808
# Epoch 3, Mean Train Loss: 0.0018880197399147956, Mean Validation Loss: 0.013400136689364238
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[51], line 3
#       1 model_egnn = EGNN_Hybrid(in_node_feats=2, coord_dim=2, hidden_dim=128, n_layers=4, edge_hidden=128, dropout=0.0, pos_residual=False)
#       2 trainer2 = Trainer(model_egnn, equivariant_train_dataset, equivariant_validation_dataset, batch_size=8, loss_fn=torch.nn.MSELoss(), epochs=100, model_name="02-Translational-Equivariant-Model.pt")
# ----> 3 trainer2.train_loop()
#
# Cell In[34], line 47, in Trainer.train_loop(self)
#      45 data = self.train_dataset[i].to(self.device)
#      46 self.optimizer.zero_grad()
# ---> 47 out = self.model(data)
#      48 loss = self.loss_fn(out, data.y)
#      49 loss.backward()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In[49], line 137, in EGNN_Hybrid.forward(self, data)
#     135 # Pass through EGNN layers
#     136 for layer in self.layers:
# --> 137     x, h = layer(x, h, edge_index, rel_disp)
#     139 # Velocity update
#     140 vel_mid = self.head_h(h)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In[49], line 70, in EGNNLayer.forward(self, x, h, edge_index, rel_disp)
#      68 m_j = scatter_add(m_ij, j, dim=0, dim_size=h.size(0))  # (N, H_e)
#      69 h_in = torch.cat([h, m_j], dim=-1)  # (N, F + H_e)
# ---> 70 h_hidden = self.phi_h(h_in)  # (N, H)
#      71 h_delta = self.h_proj(h_hidden)  # (N, F)
#      72 h_out = h + h_delta
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
def model2_rollouts(model, dataset, positions_dataset, timesteps=1000, device='cuda', mode="residual", width = 1000, height = 1000):
    """
    Predict the rollouts of the model on the dataset starting from the idx

    Args:
        model: PyTorch model
        dataset: PyTorch dataset
        timesteps: Number of timesteps to predict
        device: Device to run the model on
        mode: "residual" or "direct"
        - In the solution above, we used the "residual" mode, where the model predicts the change in position and velocity
        - In the "direct" mode, the model predicts the position and velocity directly (if you do not intend to use this mode, you can ignore this argument)
        width: Width of the PBC box
        height: Height of the PBC box
    Returns:
        rollouts: Rollouts of the model on the dataset
        - Should be a torch tensor of shape (Batch, Timesteps, Boids, Node_dim)
    """
    rollouts = torch.empty((len(dataset), timesteps, dataset[0].x.shape[0], dataset[0].x.shape[1]), device=device)
    print(rollouts.shape)

    model.to(device)
    model.eval()
    with torch.no_grad():
        for i in range(len(dataset)):
            data = dataset[i].to(device)
            init_pos = positions_dataset[i].to(device)

            rollouts[i, 0, :, :2] = init_pos
            rollouts[i, 0, :, 2:] = data.x[:, 2:]
            current_state = data.x.clone()
            current_state[:, :2] = init_pos
            for t in range(1, timesteps):
                data.x = current_state
                out = model(data)
                if mode == "residual":
                    current_state[:, :2] += out[:, :2]  
                    current_state[:, 2:] += out[:, 2:] 

                current_state[:, 0] = current_state[:, 0] % width   # PBC for x position
                current_state[:, 1] = current_state[:, 1] % height  # PBC for y position
                
                rollouts[i, t] = current_state
                if t % 100 == 0:
                    print(f"Predicted timestep {t} for trajectory {i}")
    

    
    return rollouts

# %%
initial_states_validation_dataset = Equivariant_Boids_Dataset2(
    raw_data_path="../../data/boids/raw/", 
    processed_data_path="../../data/boids/processed/", 
    root="../../data/boids/", 
    solution_idx_range=(16, 25), 
    timesteps=2, 
    processed_file_name="AR1_VAL_Boids_Equivariant.pt",
    transform=keep_01
    ) 

print(initial_states_validation_dataset[1])

translational_equivariant_model_rollout = model2_rollouts(translational_equivariant_model, initial_states_validation_dataset, init_val_positions.to(device), timesteps=1000, device=device)
# Out:
# Data(x=[25, 4], edge_index=[2, 600], y=[25, 4])
# torch.Size([9, 1000, 25, 4])
# Predicted timestep 100 for trajectory 0
# Predicted timestep 200 for trajectory 0
# Predicted timestep 300 for trajectory 0
# Predicted timestep 400 for trajectory 0
# Predicted timestep 500 for trajectory 0
# Predicted timestep 600 for trajectory 0
# Predicted timestep 700 for trajectory 0
# Predicted timestep 800 for trajectory 0
# Predicted timestep 900 for trajectory 0
# Predicted timestep 100 for trajectory 1
# Predicted timestep 200 for trajectory 1
# Predicted timestep 300 for trajectory 1
# Predicted timestep 400 for trajectory 1
# Predicted timestep 500 for trajectory 1
# Predicted timestep 600 for trajectory 1
# Predicted timestep 700 for trajectory 1
# Predicted timestep 800 for trajectory 1
# Predicted timestep 900 for trajectory 1
# Predicted timestep 100 for trajectory 2
# Predicted timestep 200 for trajectory 2
# Predicted timestep 300 for trajectory 2
# Predicted timestep 400 for trajectory 2
# Predicted timestep 500 for trajectory 2
# Predicted timestep 600 for trajectory 2
# Predicted timestep 700 for trajectory 2
# Predicted timestep 800 for trajectory 2
# Predicted timestep 900 for trajectory 2
# Predicted timestep 100 for trajectory 3
# Predicted timestep 200 for trajectory 3
# Predicted timestep 300 for trajectory 3
# Predicted timestep 400 for trajectory 3
# Predicted timestep 500 for trajectory 3
# Predicted timestep 600 for trajectory 3
# Predicted timestep 700 for trajectory 3
# Predicted timestep 800 for trajectory 3
# Predicted timestep 900 for trajectory 3
# Predicted timestep 100 for trajectory 4
# Predicted timestep 200 for trajectory 4
# Predicted timestep 300 for trajectory 4
# Predicted timestep 400 for trajectory 4
# Predicted timestep 500 for trajectory 4
# Predicted timestep 600 for trajectory 4
# Predicted timestep 700 for trajectory 4
# Predicted timestep 800 for trajectory 4
# Predicted timestep 900 for trajectory 4
# Predicted timestep 100 for trajectory 5
# Predicted timestep 200 for trajectory 5
# Predicted timestep 300 for trajectory 5
# Predicted timestep 400 for trajectory 5
# Predicted timestep 500 for trajectory 5
# Predicted timestep 600 for trajectory 5
# Predicted timestep 700 for trajectory 5
# Predicted timestep 800 for trajectory 5
# Predicted timestep 900 for trajectory 5
# Predicted timestep 100 for trajectory 6
# Predicted timestep 200 for trajectory 6
# Predicted timestep 300 for trajectory 6
# Predicted timestep 400 for trajectory 6
# Predicted timestep 500 for trajectory 6
# Predicted timestep 600 for trajectory 6
# Predicted timestep 700 for trajectory 6
# Predicted timestep 800 for trajectory 6
# Predicted timestep 900 for trajectory 6
# Predicted timestep 100 for trajectory 7
# Predicted timestep 200 for trajectory 7
# Predicted timestep 300 for trajectory 7
# Predicted timestep 400 for trajectory 7
# Predicted timestep 500 for trajectory 7
# Predicted timestep 600 for trajectory 7
# Predicted timestep 700 for trajectory 7
# Predicted timestep 800 for trajectory 7
# Predicted timestep 900 for trajectory 7
# Predicted timestep 100 for trajectory 8
# Predicted timestep 200 for trajectory 8
# Predicted timestep 300 for trajectory 8
# Predicted timestep 400 for trajectory 8
# Predicted timestep 500 for trajectory 8
# Predicted timestep 600 for trajectory 8
# Predicted timestep 700 for trajectory 8
# Predicted timestep 800 for trajectory 8
# Predicted timestep 900 for trajectory 8

# %% [markdown]
# Above, we show the boids with their radius of effect. As expected, boids who are farther than `radius=40` units away from eachother, are shown to not affect eachother.
#
# So in our dataset, we form undirected edges between nodes with a max PBC distance of 40 units.

# %% [markdown]
# # E(n) Equivariant Graph Neural Networks

# %% [markdown]
# In Satorras, Hoogeboom, Welling's paper [3] with the same name, they introduce a relatively simple model that is equivariant to E(n) transformations.
# You can check the official [implementation](https://github.com/vgsatorras/egnn).

# %% [markdown]
# # Push-forward training

# %%
# class Pushforward_Equivariant_Boids_Dataset(InMemoryDataset):
#     def __init__(self, raw_data_path, processed_data_path, root=None, transform=None, pre_transform=None, post_transform=None, solution_idx_range=(0, 25), timesteps=1000, processed_file_name="AR1_Boids.pt", L = 1000):
#         self.raw_data_path = raw_data_path
#         self.processed_data_path = processed_data_path
#         self.solution_idx_range = solution_idx_range
#         self.timesteps = timesteps
#         self.processed_file_name = processed_file_name
#         self.pre_transform = pre_transform
#         self.transform = transform
#         self.post_transform = post_transform
#         self.L = L
#         super(Pushforward_Equivariant_Boids_Dataset, self).__init__(root, transform, pre_transform)
#         self.data, self.slices = torch.load(self.processed_paths[0], weights_only=False) #TODO check this

#     @property
#     def processed_file_names(self):
#         return [self.processed_file_name]

#     @property
#     def raw_file_names(self):
#         return [pfn for pfn in os.listdir(self.raw_data_path) if (self.solution_idx_range[0] <= int(pfn.split("_")[-1][:-4]) < self.solution_idx_range[1])]
    
#     def download(self):
#         pass
    
#     # def __len__(self):
#     #     return (self.timesteps - 1) * (self.solution_idx_range[1] - self.solution_idx_range[0])

#     def process(self):
#         # TODO: TODO: TODO: TODO: TODO:
#         """
#         Your code goes here.

#         Process the raw data and save the processed data to disk, see the AR_Boids_Dataset for an example.
        
#         HINT: Make sure your learning task adheres to the PBC constraints - depending on your approach, 
#         you may need to include the PBC constraints in the data processing step.
#         """
#         max_forward_steps = 5
#         data_list = []
#         init_positions_list = []

#         for idx, raw_path in enumerate(self.raw_file_names):
#             trajectory = np.load(self.raw_data_path + raw_path)

#             init_positions_list.append(torch.tensor(trajectory[0, :, :2], dtype=torch.float))

#             if self.transform is not None:
#                 trajectory = self.transform(trajectory)
#             if self.pre_transform is not None:
#                 trajectory = self.pre_transform(trajectory)

#             trajectory = self.apply_pbc(trajectory)

#             for t in range(trajectory.shape[0] - max_forward_steps):
#                 x = torch.tensor(trajectory[t], dtype=torch.float)
                
#                 # Collect the sequence of ground-truth changes
#                 y_sequence = []
#                 for step in range(max_forward_steps):
#                     #print(step)
#                     current_pos = torch.tensor(trajectory[t + step, :, :2], dtype=torch.float)
#                     next_pos = torch.tensor(trajectory[t + step + 1, :, :2], dtype=torch.float)

#                     # Calculate displacement with PBC
#                     dx = (next_pos - current_pos)
#                     dx[dx > self.L / 2] -= self.L
#                     dx[dx < -self.L / 2] += self.L

#                     # Calculate velocity change
#                     dv = torch.tensor(trajectory[t + step + 1, :, 2:] - trajectory[t + step, :, 2:], dtype=torch.float)

#                     y_step = torch.cat([dx, dv], dim=-1)
#                     y_sequence.append(y_step)
                
#                 # Stack into a tensor: [max_forward_steps, num_boids, features]
#                 y_tensor_3d = torch.stack(y_sequence, dim=0) 
#                 #print(y_tensor_3d.shape)
#                 y = y_tensor_3d.permute(1, 0, 2).reshape(x.shape[0], -1)
#                 #print(y.shape)
#                 edge_index = torch.tensor([[i, j] for i in range(x.shape[0]) for j in range(x.shape[0]) if i != j], dtype=torch.long).t().contiguous()
                
#                 data = Data(x=x, y=y, edge_index=edge_index)
#                 data_list.append(data)

#         init_positions = torch.stack(init_positions_list)
#         positions_file = os.path.join(self.processed_dir, "positions_" + self.processed_file_name)
#         print("Saving initial positions to:", positions_file)
#         torch.save(init_positions, positions_file)
#         data, slices = self.collate(data_list)
#         torch.save((data, slices), self.processed_paths[0])
        

#     def apply_pbc(self, trajectory):
#         """
#         Apply periodic boundary conditions to the trajectory.

#         Args:
#             trajectory: Numpy array of shape (Timesteps, Boids, Node_dim)
#         Returns:
#             trajectory: Numpy array of shape (Timesteps, Boids, Node_dim) with PBC applied
#         """
#         trajectory[:, :, 0] = trajectory[:, :, 0] % self.L   # PBC for x position
#         trajectory[:, :, 1] = trajectory[:, :, 1] % self.L   # PBC for y position
#         return trajectory


#     def __getitem__(self, idx):
#         return self.get(idx)
    
#     def __repr__(self):
#         return f'{self.__class__.__name__}({len(self)})'

# %%
from tqdm import trange

class Pushforward_Equivariant_Boids_Dataset(InMemoryDataset):
    def __init__(self, raw_data_path, processed_data_path, root=None,
                 transform=None, pre_transform=None, post_transform=None,
                 solution_idx_range=(0, 25), timesteps=1000,
                 processed_file_name="AR1_Boids_Equivariant.pt", L=1000):
        self.raw_data_path = raw_data_path
        self.processed_data_path = processed_data_path
        self.solution_idx_range = solution_idx_range
        self.timesteps = timesteps
        self.processed_file_name = processed_file_name
        self.pre_transform = pre_transform
        self.transform = transform
        self.post_transform = post_transform
        self.L = L
        super(Pushforward_Equivariant_Boids_Dataset, self).__init__(root, transform, pre_transform)
        self.data, self.slices = torch.load(self.processed_paths[0], weights_only=False)

    @property
    def processed_file_names(self):
        return [self.processed_file_name]

    @property
    def raw_file_names(self):
        return [pfn for pfn in os.listdir(self.raw_data_path)
                if (self.solution_idx_range[0] <= int(pfn.split("_")[-1][:-4]) < self.solution_idx_range[1])]

    def download(self):
        pass

    # def __len__(self):
    #     return (self.timesteps - 1) * (self.solution_idx_range[1] - self.solution_idx_range[0])

    def process(self):
        max_forward_steps = 5
        data_list = []
        all_init_positions = []   
        vmax = 0.0
        for raw_path in self.raw_file_names:
            trajectory = np.load(os.path.join(self.raw_data_path, raw_path))  
            vels = trajectory[:, :, 2:]  
            vmax = max(vmax, np.abs(vels).max())
        if vmax == 0:
            vmax = 1.0

        print(f"[Normalization] Using L={self.L}, vmax={vmax:.4f}")

        for raw_path in self.raw_file_names:
            trajectory = np.load(os.path.join(self.raw_data_path, raw_path))

            init_pos = torch.tensor(trajectory[0, :, :2], dtype=torch.float)  
            all_init_positions.append(init_pos)

            for t in range(trajectory.shape[0] - max_forward_steps):
                pos_t = torch.tensor(trajectory[t, :, :2], dtype=torch.float) / self.L
                vel_t = torch.tensor(trajectory[t, :, 2:], dtype=torch.float) / vmax
                x = torch.cat([pos_t, vel_t], dim=-1) 

                y_sequence = []
                for step in range(max_forward_steps):

                    pos_next = torch.tensor(trajectory[t+1 + step, :, :2], dtype=torch.float) / self.L
                    vel_next = torch.tensor(trajectory[t+1 + step, :, 2:], dtype=torch.float) / vmax
                    y_sequence.append(torch.cat([pos_next, vel_next], dim=-1))

                y_tensor_3d = torch.stack(y_sequence, dim=0)  # (T, N, F)
                y = y_tensor_3d.permute(1, 0, 2).reshape(x.shape[0], -1)  # (N, T*F)


                N = pos_t.shape[0]
                edge_index = torch.combinations(torch.arange(N), r=2, with_replacement=False).T
                edge_index = torch.cat([edge_index, edge_index.flip(0)], dim=1)
                senders, receivers = edge_index

                rel_disp = pos_t[receivers] - pos_t[senders]
                rel_disp = rel_disp - torch.round(rel_disp)
                edge_attr = rel_disp

                data = Data(x=x, edge_index=edge_index, edge_attr=edge_attr, y=y)
                data_list.append(data)

        data, slices = self.collate(data_list)
        torch.save((data, slices), self.processed_paths[0])

        all_init_positions = torch.stack(all_init_positions)   
        torch.save(all_init_positions, os.path.join(self.processed_data_path,
                                                    "positions_" + self.processed_file_name))
        print(f"Saved initial positions: {all_init_positions.shape}")
        
    def __getitem__(self, idx):
        return self.get(idx)
    
    def __repr__(self):
        return f'{self.__class__.__name__}({len(self)})'

# %%
pushforward_equivariant_train_dataset2 = Pushforward_Equivariant_Boids_Dataset(
    raw_data_path="../../data/boids/raw/", 
    processed_data_path="../../data/boids/processed/", 
    root="../../data/boids/", 
    solution_idx_range=(0, 15), 
    timesteps=1000, 
    processed_file_name="AR1_Boids_Equivariant1991.pt"
    )

pushforward_equivariant_validation_dataset2 = Pushforward_Equivariant_Boids_Dataset(
    raw_data_path="../../data/boids/raw/", 
    processed_data_path="../../data/boids/processed/", 
    root="../../data/boids/", 
    solution_idx_range=(16, 25), 
    timesteps=1000, 
    processed_file_name="AR1_VAL_Boids_Equivariant1991.pt"
    )
# Out:
# Processing...
# [Normalization] Using L=1000, vmax=6.0000
# Saved initial positions: torch.Size([15, 25, 2])
# [Normalization] Using L=1000, vmax=6.0000
# Done!
# Processing...
# Saved initial positions: torch.Size([9, 25, 2])
# Done!

# %%
pushforward_equivariant_train_dataset2[0]
# Out:
# Data(x=[25, 4], edge_index=[2, 600], edge_attr=[600, 2], y=[25, 20])

# %%
max_forward_steps = 4

# %%
def _pushforward_schedule(epoch, max_forward_steps=5):
    if epoch < 20:
        return 1
    elif epoch < 30:
        return 2
    elif epoch < 50:
        return 3
    else:
        return max_forward_steps
    

class Trainer2:
    def __init__(self, model, train_dataset, validation_dataset, batch_size=1, lr=0.0001, epochs=100, loss_fn=torch.nn.MSELoss(), model_name= "01-AR-Set-Model.pt"):
        """
        Simple Trainer class to train a PyTorch (geometric) model on a dataset.

        Args:
            model: PyTorch model to train
            train_dataset: PyTorch dataset to train on
            validation_dataset: PyTorch dataset to validate on
            batch_size: Batch size for training
            lr: Learning rate
            epochs: Number of epochs to train for
            loss_fn: Loss function to use
        """
        self.model = model
        self.train_dataset = train_dataset
        self.validation_dataset = validation_dataset
        self.batch_size = batch_size
        self.lr = lr
        self.epochs = epochs
        self.loss_fn = loss_fn
        self.model_name = model_name

        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        print("Using device:", self.device)
        self.model.to(self.device)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=self.lr)

        self.train_loader = self.make_data_loader(self.train_dataset)
        self.validation_loader = self.make_data_loader(self.validation_dataset, shuffle=False)

    def make_data_loader(self, dataset, shuffle=True):
        return DataLoader(dataset, batch_size=self.batch_size, shuffle=shuffle)
    
    def train_loop_pushforward(self, L=1000, max_forward_steps=5):
        best_model_loss = np.inf

        for epoch in range(self.epochs):
            self.model.train()
            forward_steps = _pushforward_schedule(epoch, max_forward_steps)
            mean_train_loss = 0

            for data in self.train_loader:
                data = data.to(self.device)
                edge_attr = getattr(data, "edge_attr", None)
                self.optimizer.zero_grad()

                current_state = data.x.clone()
                batch_loss = 0
                ground_truth_ys = data.y
                num_features = 4

                for t in range(forward_steps):

                    # Pass coordinates and velocity as node features
                    out = self.model(Data(x=current_state,edge_index=data.edge_index, edge_attr=edge_attr))

                    # Compute loss
                    start_idx = t * num_features
                    end_idx = (t + 1) * num_features
                    true_y_at_step_t = ground_truth_ys[:, start_idx:end_idx]
                    batch_loss += self.loss_fn(out, true_y_at_step_t)

                    # Update state safely (out-of-place)
                    #TODO we do not do that anymore
                    new_coords = out[:, :2]      # apply PBC
                    new_velocity = out[:, 2:]
                    current_state = torch.cat([new_coords, new_velocity], dim=1)

                batch_loss.backward()
                self.optimizer.step()
                mean_train_loss += batch_loss.item()

            mean_train_loss /= len(self.train_loader)

            # Validation
            self.model.eval()
            mean_val_loss = 0
            with torch.no_grad():
                for data in self.validation_loader:
                    data = data.to(self.device)
                    edge_attr = getattr(data, "edge_attr", None)
                    current_state = data.x.clone()
                    ground_truth_ys = data.y
                    batch_val_loss = 0

                    for t in range(forward_steps):

                        out = self.model(Data(x=current_state, edge_index=data.edge_index, edge_attr=data.edge_attr))

                        start_idx = t * num_features
                        end_idx = (t + 1) * num_features
                        true_y_at_step_t = ground_truth_ys[:, start_idx:end_idx]
                        batch_val_loss += self.loss_fn(out, true_y_at_step_t)

                        # Update state safely
                        new_coords =  out[:, :2]
                        new_velocity = out[:, 2:]
                        current_state = torch.cat([new_coords, new_velocity], dim=1)

                    mean_val_loss += batch_val_loss.item()

            mean_val_loss /= len(self.validation_loader)

            # Save best model
            if mean_val_loss < best_model_loss:
                best_model_loss = mean_val_loss
                torch.save(self.model.state_dict(), f"../../models/{self.model_name}")

            print(f"Epoch {epoch}, Mean Train Loss: {mean_train_loss}, Mean Validation Loss: {mean_val_loss}")

# %%
model = EGNN_Hybrid(in_node_feats=2, coord_dim=2, hidden_dim=128, n_layers=4, edge_hidden=128, dropout=0.0, pos_residual=False)

trainer = Trainer2(model, pushforward_equivariant_train_dataset2, pushforward_equivariant_validation_dataset2, batch_size=8, loss_fn=torch.nn.MSELoss(), epochs=100, model_name="03-Rotational-Equivariant-Model54.pt")
trainer.train_loop_pushforward()
# Out:
# Using device: cuda
# Epoch 0, Mean Train Loss: 0.011396886848326364, Mean Validation Loss: 0.0015818685986622378
# Epoch 1, Mean Train Loss: 0.0015682926376552578, Mean Validation Loss: 0.0015222671349452606
# Epoch 2, Mean Train Loss: 0.0014970709512897586, Mean Validation Loss: 0.0015115704445471628
# Epoch 3, Mean Train Loss: 0.0014936665973705949, Mean Validation Loss: 0.001428877374478686
# Epoch 4, Mean Train Loss: 0.0014759986457795926, Mean Validation Loss: 0.0016240744350138163
# Epoch 5, Mean Train Loss: 0.0014661725324509706, Mean Validation Loss: 0.0014633362498541048
# Epoch 6, Mean Train Loss: 0.0014605571020806462, Mean Validation Loss: 0.0014998275789561636
# Epoch 7, Mean Train Loss: 0.0014542876510990658, Mean Validation Loss: 0.0015086729320468555
# Epoch 8, Mean Train Loss: 0.001451303780060702, Mean Validation Loss: 0.0014981372632194376
# Epoch 9, Mean Train Loss: 0.0014433990767710094, Mean Validation Loss: 0.0014231746805360703
# Epoch 10, Mean Train Loss: 0.001442475539548051, Mean Validation Loss: 0.001486644946027939
# Epoch 11, Mean Train Loss: 0.001439592808563858, Mean Validation Loss: 0.001424853904963389
# Epoch 12, Mean Train Loss: 0.001437391300121735, Mean Validation Loss: 0.001446615628822201
# Epoch 13, Mean Train Loss: 0.0014336987565289913, Mean Validation Loss: 0.0014296435638040553
# Epoch 14, Mean Train Loss: 0.0014327177304208293, Mean Validation Loss: 0.0014392501913992614
# Epoch 15, Mean Train Loss: 0.0014324364518493175, Mean Validation Loss: 0.001420497881495716
# Epoch 16, Mean Train Loss: 0.0014280615870000627, Mean Validation Loss: 0.001453395957491921
# Epoch 17, Mean Train Loss: 0.0014273899296712847, Mean Validation Loss: 0.0014273997430710292
# Epoch 18, Mean Train Loss: 0.0014252301986952597, Mean Validation Loss: 0.001440128008824461
# Epoch 19, Mean Train Loss: 0.0014260332027051094, Mean Validation Loss: 0.0014785947190716798
# Epoch 20, Mean Train Loss: 0.00438183963374817, Mean Validation Loss: 0.0044131556551162375
# Epoch 21, Mean Train Loss: 0.004325513495214211, Mean Validation Loss: 0.004295892682723336
# Epoch 22, Mean Train Loss: 0.004316056561986327, Mean Validation Loss: 0.004360719340021595
# Epoch 23, Mean Train Loss: 0.004322115593042827, Mean Validation Loss: 0.004304259555351564
# Epoch 24, Mean Train Loss: 0.004316040544745485, Mean Validation Loss: 0.004310025856872406
# Epoch 25, Mean Train Loss: 0.004313193183712928, Mean Validation Loss: 0.004310903319378667
# Epoch 26, Mean Train Loss: 0.004308639803019403, Mean Validation Loss: 0.00434089852523292
# Epoch 27, Mean Train Loss: 0.00431135312152965, Mean Validation Loss: 0.004468004457430652
# Epoch 28, Mean Train Loss: 0.004311634994381376, Mean Validation Loss: 0.004303658067130657
# Epoch 29, Mean Train Loss: 0.004305905249989488, Mean Validation Loss: 0.004355463362779639
# Epoch 30, Mean Train Loss: 0.008755797544423898, Mean Validation Loss: 0.008830930584411232
# Epoch 31, Mean Train Loss: 0.008700431537985255, Mean Validation Loss: 0.008811194034374888
# Epoch 32, Mean Train Loss: 0.008707907696770559, Mean Validation Loss: 0.00880594681698962
# Epoch 33, Mean Train Loss: 0.008693117102674092, Mean Validation Loss: 0.008807028657494291
# Epoch 34, Mean Train Loss: 0.008692208918603898, Mean Validation Loss: 0.008711776144179697
# Epoch 35, Mean Train Loss: 0.0086949239367911, Mean Validation Loss: 0.008666031475208261
# Epoch 36, Mean Train Loss: 0.008689970789598387, Mean Validation Loss: 0.008818313517674271
# Epoch 37, Mean Train Loss: 0.00869559864337487, Mean Validation Loss: 0.008974318301378454
# Epoch 38, Mean Train Loss: 0.008690100751146809, Mean Validation Loss: 0.008687965047322775
# Epoch 39, Mean Train Loss: 0.008686729387882652, Mean Validation Loss: 0.008771523534531818
# Epoch 40, Mean Train Loss: 0.008685234725287962, Mean Validation Loss: 0.0086813179856173
# Epoch 41, Mean Train Loss: 0.008680900647840863, Mean Validation Loss: 0.008793964087076996
# Epoch 42, Mean Train Loss: 0.008680253467257539, Mean Validation Loss: 0.008696024613781057
# Epoch 43, Mean Train Loss: 0.008684674474297915, Mean Validation Loss: 0.008730234250697322
# Epoch 44, Mean Train Loss: 0.008683594978897482, Mean Validation Loss: 0.008734215722142835
# Epoch 45, Mean Train Loss: 0.008683100662338994, Mean Validation Loss: 0.008761926559821274
# Epoch 46, Mean Train Loss: 0.008681060938185305, Mean Validation Loss: 0.00869675301168432
# Epoch 47, Mean Train Loss: 0.008675798387664104, Mean Validation Loss: 0.008662153089380809
# Epoch 48, Mean Train Loss: 0.008672714036081953, Mean Validation Loss: 0.008742007605477348
# Epoch 49, Mean Train Loss: 0.008673198790027932, Mean Validation Loss: 0.008670164743710173
# Epoch 50, Mean Train Loss: 0.022188041818171984, Mean Validation Loss: 0.022198211656567376
# Epoch 51, Mean Train Loss: 0.022023162600973128, Mean Validation Loss: 0.022109488032115873
# Epoch 52, Mean Train Loss: 0.02201868575556695, Mean Validation Loss: 0.02236506645042807
# Epoch 53, Mean Train Loss: 0.021975599914757508, Mean Validation Loss: 0.022196831269814407
# Epoch 54, Mean Train Loss: 0.022004029766226233, Mean Validation Loss: 0.022720867433911607
# Epoch 55, Mean Train Loss: 0.022001250697729565, Mean Validation Loss: 0.02238005018152762
# Epoch 56, Mean Train Loss: 0.021998441825662754, Mean Validation Loss: 0.02211175454808004
# Epoch 57, Mean Train Loss: 0.0219951142492207, Mean Validation Loss: 0.02240653511414296
# Epoch 58, Mean Train Loss: 0.022002611196929808, Mean Validation Loss: 0.022222956195296968
# Epoch 59, Mean Train Loss: 0.021998211641377687, Mean Validation Loss: 0.022093011586808382
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 4
#       1 model = EGNN_Hybrid(in_node_feats=2, coord_dim=2, hidden_dim=128, n_layers=4, edge_hidden=128, dropout=0.0, pos_residual=False)
#       3 trainer = Trainer2(model, pushforward_equivariant_train_dataset2, pushforward_equivariant_validation_dataset2, batch_size=8, loss_fn=torch.nn.MSELoss(), epochs=100, model_name="03-Rotational-Equivariant-Model54.pt")
# ----> 4 trainer.train_loop_pushforward()
#
# Cell In[19], line 81, in Trainer2.train_loop_pushforward(self, L, max_forward_steps)
#      78     new_velocity = out[:, 2:]
#      79     current_state = torch.cat([new_coords, new_velocity], dim=1)
# ---> 81 batch_loss.backward()
#      82 self.optimizer.step()
#      83 mean_train_loss += batch_loss.item()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\autograd\graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
sample = pushforward_equivariant_train_dataset2[0]
print(sample)
# Out:
# Data(x=[25, 4], edge_index=[2, 600], edge_attr=[600, 2], y=[25, 20])

# %% [markdown]
# ## Evaluating scientific AI models
#
# The Boids simulations are very sensitive to changes in the initial state. Slight changes in the initial state can lead to drastically different final states. Similarly, emulations (the neural network predictions) can accumulate errors very quickly.
#
# Using MSE to compare models to the ground truth or to each other here does not account for this error accumulation. As a result, a likely generated/predicted trajectory can have high MSE.
#
# Luckily for us, there are usually better ways to evaluate models! When working in an interdisciplinary group, the physics wizards will propose a metric that should hold true even when trajectories diverge, or our predictions suffer from accumulating errors.
#
# In the Boids setting, we can investigate the distribution of velocities, since these should (hopefully) remain invariant even under diverging trajectories / error accumulation.
#
# If we plot them visually, we want to investigate how different the predicted velocity distributions are from the ground truth velocity distributions. However, since we have to investigate the distributions for each timestep, let's use the Kullback-Leibler Divergence ($D_\text{KL}$) metric to measure the difference. For two distributions $P$ and $Q$, it is defined as follows:
#
#
# $D_\text{KL}(P||Q) = \int p(x) \ln \frac{p(x)}{q(x)} \text{d} x $
#
#
# ![KL Divergence](https://hugocisneros.com/ox-hugo/forwardvsreversedKL.jpg)
#
#
# The $D_\text{KL}$ between two distributions $P$ and $Q$ is asymmetric, meaning $D_\text{KL}(P||Q) \neq D_\text{KL}(Q||P)$, as illustrated above.
#
# Since we care more whether the predicted distribution $Q$ fits under the ground truth distribution $P$, we will use the reverse KL: $D_\text{KL}(Q||P)$

# %%
def compare_distributions(dist1, dist2):
    """
    Compare two distributions by computing the KL divergence

    Args:
        dist1: torch.distributions.Distribution
        dist2: torch.distributions.Distribution
    """
    kl = torch.distributions.kl_divergence(dist1, dist2)
    return kl

def compute_distribution_per_timestep(data, timesteps):
    """
    Compute the distribution of the data per timestep

    Args:
        data: torch.Tensor of shape (T, N, 4)
        timesteps: int, number of timesteps to compute the distribution for

    Returns:
        list of torch.distributions.Normal
    """
    distributions = []
    for t in range(timesteps):
        # Compute the mean and std of the data
        mean = data[:, t, :, :].mean()
        std = data[:, t, :, :].std()
        dist = torch.distributions.Normal(mean, std)
        distributions.append(dist)
    return distributions

def compute_mean_kl_divergence(data, distributions):
    """
    Compute the mean KL divergence between the data and the distributions

    Args:
        data: torch.Tensor of shape (T, N, 4)
        distributions: list of torch.distributions.Normal

    Returns:
        float
    """
    kl_divergences = []
    for t in range(data.shape[0]):
        kl = compare_distributions(distributions[t], data[t, :, :])
        kl_divergences.append(kl)
    return torch.tensor(kl_divergences).mean()

def plot_kl_divergence(distributions1, distributions2, title="KL Divergence between <distributions1> and <distributions2>"):
    """
    Plot the KL divergence between the data and the distributions

    Args:
        distributions1: list of torch.distributions.Normal
        distributions2: list of torch.distributions.Normal
    """
    kl_divergences = []
    for t in range(len(distributions1)):
        kl = compare_distributions(distributions1[t], distributions2[t]).cpu().numpy()
        kl_divergences.append(kl)


    plt.plot(kl_divergences)
    plt.xlabel("Timestep")
    plt.ylabel("KL Divergence")
    plt.title(title)
    plt.show()

# %%
ar_set_model_rollout
# Out:
# tensor([[[[ 1.2400e+02,  7.1500e+02, -5.0000e+00, -3.0000e+00],
#           [ 1.5700e+02,  3.6800e+02, -5.0000e+00,  3.0000e+00],
#           [ 8.2000e+02,  6.4400e+02, -3.0000e+00,  5.0000e+00],
#           ...,
#           [ 9.1400e+02,  9.6200e+02,  5.0000e+00,  3.0000e+00],
#           [ 6.8000e+02,  4.1900e+02,  5.0000e+00,  5.0000e+00],
#           [ 1.1800e+02,  9.1600e+02,  5.0000e+00, -3.0000e+00]],
#
#          [[ 1.2182e+02,  7.1502e+02, -2.6895e+00, -7.6737e-01],
#           [ 1.5482e+02,  3.6802e+02, -2.6895e+00,  5.2326e+00],
#           [ 8.1782e+02,  6.4402e+02, -6.8949e-01,  7.2326e+00],
#           ...,
#           [ 9.1182e+02,  9.6202e+02,  7.3105e+00,  5.2326e+00],
#           [ 6.7782e+02,  4.1902e+02,  7.3105e+00,  7.2326e+00],
#           [ 1.1582e+02,  9.1602e+02,  7.3105e+00, -7.6737e-01]],
#
#          [[ 1.1938e+02,  7.1500e+02, -1.0768e+00,  1.1457e+00],
#           [ 1.5238e+02,  3.6800e+02, -1.0768e+00,  7.1457e+00],
#           [ 8.1538e+02,  6.4400e+02,  9.2317e-01,  9.1457e+00],
#           ...,
#           [ 9.0938e+02,  9.6200e+02,  8.9232e+00,  7.1457e+00],
#           [ 6.7538e+02,  4.1900e+02,  8.9232e+00,  9.1457e+00],
#           [ 1.1338e+02,  9.1600e+02,  8.9232e+00,  1.1457e+00]],
#
#          ...,
#
#          [[        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           ...,
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan]],
#
#          [[        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           ...,
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan]],
#
#          [[        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           ...,
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan]]],
#
#
#         [[[ 3.3000e+02,  8.8900e+02,  3.0000e+00, -4.0000e+00],
#           [ 8.5300e+02,  5.2300e+02,  5.0000e+00,  3.0000e+00],
#           [ 3.7500e+02,  2.8500e+02, -5.0000e+00, -4.0000e+00],
#           ...,
#           [ 6.5700e+02,  5.9300e+02,  3.0000e+00,  4.0000e+00],
#           [ 3.8100e+02,  3.5100e+02,  4.0000e+00,  5.0000e+00],
#           [ 8.5400e+02,  5.2300e+02, -5.0000e+00, -4.0000e+00]],
#
#          [[ 3.3144e+02,  8.8958e+02,  4.0582e+00, -4.2511e-01],
#           [ 8.5444e+02,  5.2358e+02,  6.0582e+00,  6.5749e+00],
#           [ 3.7644e+02,  2.8558e+02, -3.9418e+00, -4.2511e-01],
#           ...,
#           [ 6.5844e+02,  5.9358e+02,  4.0582e+00,  7.5749e+00],
#           [ 3.8244e+02,  3.5158e+02,  5.0582e+00,  8.5749e+00],
#           [ 8.5544e+02,  5.2358e+02, -3.9418e+00, -4.2511e-01]],
#
#          [[ 3.3279e+02,  8.8992e+02,  4.5938e+00,  3.3172e+00],
#           [ 8.5579e+02,  5.2392e+02,  6.5938e+00,  1.0317e+01],
#           [ 3.7779e+02,  2.8592e+02, -3.4062e+00,  3.3172e+00],
#           ...,
#           [ 6.5979e+02,  5.9392e+02,  4.5938e+00,  1.1317e+01],
#           [ 3.8379e+02,  3.5192e+02,  5.5938e+00,  1.2317e+01],
#           [ 8.5679e+02,  5.2392e+02, -3.4062e+00,  3.3172e+00]],
#
#          ...,
#
#          [[        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           ...,
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan]],
#
#          [[        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           ...,
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan]],
#
#          [[        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           ...,
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan]]],
#
#
#         [[[ 1.0100e+02,  9.7000e+01,  4.0000e+00, -5.0000e+00],
#           [ 9.9800e+02,  9.8900e+02, -4.0000e+00, -3.0000e+00],
#           [ 6.9300e+02,  8.1400e+02,  3.0000e+00, -3.0000e+00],
#           ...,
#           [ 2.0000e+02,  9.8300e+02, -4.0000e+00, -5.0000e+00],
#           [ 5.8000e+02,  9.4700e+02,  5.0000e+00,  5.0000e+00],
#           [ 1.9700e+02,  8.7000e+02,  5.0000e+00,  4.0000e+00]],
#
#          [[ 9.5706e+01,  8.9593e+01, -4.0635e+00, -1.0222e+01],
#           [ 9.9271e+02,  9.8159e+02, -1.2063e+01, -8.2217e+00],
#           [ 6.8771e+02,  8.0659e+02, -5.0635e+00, -8.2217e+00],
#           ...,
#           [ 1.9471e+02,  9.7559e+02, -1.2063e+01, -1.0222e+01],
#           [ 5.7471e+02,  9.3959e+02, -3.0635e+00, -2.2167e-01],
#           [ 1.9171e+02,  8.6259e+02, -3.0635e+00, -1.2217e+00]],
#
#          [[ 9.0970e+01,  8.1564e+01, -9.5317e+00, -1.3933e+01],
#           [ 9.8797e+02,  9.7356e+02, -1.7532e+01, -1.1933e+01],
#           [ 6.8297e+02,  7.9856e+02, -1.0532e+01, -1.1933e+01],
#           ...,
#           [ 1.8997e+02,  9.6756e+02, -1.7532e+01, -1.3933e+01],
#           [ 5.6997e+02,  9.3156e+02, -8.5317e+00, -3.9330e+00],
#           [ 1.8697e+02,  8.5456e+02, -8.5317e+00, -4.9330e+00]],
#
#          ...,
#
#          [[        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           ...,
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan]],
#
#          [[        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           ...,
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan]],
#
#          [[        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           ...,
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan]]],
#
#
#         ...,
#
#
#         [[[ 2.9400e+02,  4.2100e+02, -5.0000e+00,  5.0000e+00],
#           [ 7.6700e+02,  2.8300e+02,  3.0000e+00, -3.0000e+00],
#           [ 7.2300e+02,  6.9000e+02, -3.0000e+00, -3.0000e+00],
#           ...,
#           [ 9.6300e+02,  2.8400e+02, -4.0000e+00,  3.0000e+00],
#           [ 9.2500e+02,  7.5700e+02,  3.0000e+00,  4.0000e+00],
#           [ 5.8900e+02,  6.6000e+01,  5.0000e+00,  3.0000e+00]],
#
#          [[ 2.9232e+02,  4.2272e+02, -5.5450e+00,  3.7187e+00],
#           [ 7.6532e+02,  2.8472e+02,  2.4550e+00, -4.2813e+00],
#           [ 7.2132e+02,  6.9172e+02, -3.5450e+00, -4.2813e+00],
#           ...,
#           [ 9.6132e+02,  2.8572e+02, -4.5450e+00,  1.7187e+00],
#           [ 9.2332e+02,  7.5872e+02,  2.4550e+00,  2.7187e+00],
#           [ 5.8732e+02,  6.7724e+01,  4.4550e+00,  1.7187e+00]],
#
#          [[ 2.9067e+02,  4.2452e+02, -5.8510e+00,  2.4304e+00],
#           [ 7.6367e+02,  2.8652e+02,  2.1490e+00, -5.5696e+00],
#           [ 7.1967e+02,  6.9352e+02, -3.8510e+00, -5.5696e+00],
#           ...,
#           [ 9.5967e+02,  2.8752e+02, -4.8510e+00,  4.3041e-01],
#           [ 9.2167e+02,  7.6052e+02,  2.1490e+00,  1.4304e+00],
#           [ 5.8567e+02,  6.9519e+01,  4.1490e+00,  4.3041e-01]],
#
#          ...,
#
#          [[        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           ...,
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan]],
#
#          [[        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           ...,
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan]],
#
#          [[        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           ...,
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan]]],
#
#
#         [[[ 4.9300e+02,  5.3400e+02, -4.0000e+00, -4.0000e+00],
#           [ 9.5800e+02,  3.2100e+02,  3.0000e+00,  5.0000e+00],
#           [ 8.8000e+02,  2.9100e+02,  3.0000e+00,  5.0000e+00],
#           ...,
#           [ 4.1400e+02,  3.3200e+02,  5.0000e+00,  5.0000e+00],
#           [ 4.5500e+02,  3.5700e+02,  3.0000e+00, -3.0000e+00],
#           [ 1.4800e+02,  9.2300e+02,  4.0000e+00,  5.0000e+00]],
#
#          [[ 4.9152e+02,  5.3442e+02, -2.4915e+00, -2.2486e+00],
#           [ 9.5652e+02,  3.2142e+02,  4.5085e+00,  6.7514e+00],
#           [ 8.7852e+02,  2.9142e+02,  4.5085e+00,  6.7514e+00],
#           ...,
#           [ 4.1252e+02,  3.3242e+02,  6.5085e+00,  6.7514e+00],
#           [ 4.5352e+02,  3.5742e+02,  4.5085e+00, -1.2486e+00],
#           [ 1.4652e+02,  9.2342e+02,  5.5085e+00,  6.7514e+00]],
#
#          [[ 4.8987e+02,  5.3480e+02, -1.4832e+00, -6.4366e-01],
#           [ 9.5488e+02,  3.2180e+02,  5.5168e+00,  8.3563e+00],
#           [ 8.7688e+02,  2.9180e+02,  5.5168e+00,  8.3563e+00],
#           ...,
#           [ 4.1087e+02,  3.3280e+02,  7.5168e+00,  8.3563e+00],
#           [ 4.5187e+02,  3.5780e+02,  5.5168e+00,  3.5634e-01],
#           [ 1.4487e+02,  9.2380e+02,  6.5168e+00,  8.3563e+00]],
#
#          ...,
#
#          [[        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           ...,
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan]],
#
#          [[        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           ...,
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan]],
#
#          [[        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           ...,
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan]]],
#
#
#         [[[ 2.0900e+02,  2.6000e+02, -4.0000e+00, -5.0000e+00],
#           [ 4.6000e+01,  8.1700e+02,  3.0000e+00, -5.0000e+00],
#           [ 7.0800e+02,  2.5800e+02, -4.0000e+00, -4.0000e+00],
#           ...,
#           [ 3.1200e+02,  1.4300e+02,  5.0000e+00,  3.0000e+00],
#           [ 9.3000e+02,  3.6100e+02,  4.0000e+00, -4.0000e+00],
#           [ 5.8000e+02,  6.8000e+02, -4.0000e+00,  4.0000e+00]],
#
#          [[ 2.0748e+02,  2.6087e+02, -3.1263e+00, -4.9334e+00],
#           [ 4.4484e+01,  8.1787e+02,  3.8737e+00, -4.9334e+00],
#           [ 7.0648e+02,  2.5887e+02, -3.1263e+00, -3.9334e+00],
#           ...,
#           [ 3.1048e+02,  1.4387e+02,  5.8737e+00,  3.0666e+00],
#           [ 9.2848e+02,  3.6187e+02,  4.8737e+00, -3.9334e+00],
#           [ 5.7848e+02,  6.8087e+02, -3.1263e+00,  4.0666e+00]],
#
#          [[ 2.0588e+02,  2.6179e+02, -2.4822e+00, -5.0475e+00],
#           [ 4.2881e+01,  8.1879e+02,  4.5178e+00, -5.0475e+00],
#           [ 7.0488e+02,  2.5979e+02, -2.4822e+00, -4.0475e+00],
#           ...,
#           [ 3.0888e+02,  1.4479e+02,  6.5178e+00,  2.9525e+00],
#           [ 9.2688e+02,  3.6279e+02,  5.5178e+00, -4.0475e+00],
#           [ 5.7688e+02,  6.8179e+02, -2.4822e+00,  3.9525e+00]],
#
#          ...,
#
#          [[        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           ...,
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan]],
#
#          [[        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           ...,
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan]],
#
#          [[        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           ...,
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan],
#           [        nan,         nan,         nan,         nan]]]],
#        device='cuda:0')

# %%
validation_files = [pfn for pfn in os.listdir("../../data/boids/raw/") if (16 <= int(pfn.split("_")[-1][:-4]) < 25)]
validation_trajectories = [np.load("../../data/boids/raw/" + f) for f in validation_files]
validation_trajectories = torch.tensor(validation_trajectories, dtype=torch.float)

dists_GT = compute_distribution_per_timestep(validation_trajectories[:,:,:,2:], 1000)
dists_AR_set = compute_distribution_per_timestep(ar_set_model_rollout[:,:,:,2:], 1000)
plot_kl_divergence(dists_AR_set, dists_GT, title="KL Divergence between AR Set Model velocities and the GT velocities per timestep")
# Out:
# C:\Users\nasso\AppData\Local\Temp\ipykernel_26000\1671957078.py:3: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_new.cpp:257.)
#   validation_trajectories = torch.tensor(validation_trajectories, dtype=torch.float)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[133], line 6
#       3 validation_trajectories = torch.tensor(validation_trajectories, dtype=torch.float)
#       5 dists_GT = compute_distribution_per_timestep(validation_trajectories[:,:,:,2:], 1000)
# ----> 6 dists_AR_set = compute_distribution_per_timestep(ar_set_model_rollout[:,:,:,2:], 1000)
#       7 plot_kl_divergence(dists_AR_set, dists_GT, title="KL Divergence between AR Set Model velocities and the GT velocities per timestep")
#
# Cell In[132], line 28, in compute_distribution_per_timestep(data, timesteps)
#      26     mean = data[:, t, :, :].mean()
#      27     std = data[:, t, :, :].std()
# ---> 28     dist = torch.distributions.Normal(mean, std)
#      29     distributions.append(dist)
#      30 return distributions
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\distributions\normal.py:59, in Normal.__init__(self, loc, scale, validate_args)
#      57 else:
#      58     batch_shape = self.loc.size()
# ---> 59 super().__init__(batch_shape, validate_args=validate_args)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\distributions\distribution.py:71, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      69         valid = constraint.check(value)
#      70         if not valid.all():
# ---> 71             raise ValueError(
#      72                 f"Expected parameter {param} "
#      73                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      74                 f"of distribution {repr(self)} "
#      75                 f"to satisfy the constraint {repr(constraint)}, "
#      76                 f"but found invalid values:\n{value}"
#      77             )
#      78 super().__init__()
#
# ValueError: Expected parameter scale (Tensor of shape ()) of distribution Normal(loc: -inf, scale: nan) to satisfy the constraint GreaterThan(lower_bound=0.0), but found invalid values:
# nan

# %%
dists_equivariant = compute_distribution_per_timestep(translational_equivariant_model_rollout, 1000)
plot_kl_divergence(dists_equivariant, dists_GT, title="KL Divergence between Translational Equivariant Model velocities and the GT velocities per timestep")

# %% [markdown]
# # References
#
# [1] Minartz, K., Poels, Y., Koop, S., & Menkovski, V. (2023). Equivariant Neural Simulators for Stochastic Spatiotemporal Dynamics. https://openreview.net/forum?id=CCVsGbhFdj
#
# [2] Reynolds, C. W. (1987) Flocks, Herds, and Schools: A Distributed Behavioral Model, in Computer Graphics, 21(4) (SIGGRAPH '87 Conference Proceedings) pages 25-34.
#
# [3] Satorras, V. G., Hoogeboom, E., & Welling, M. (2021, July). E (n) equivariant graph neural networks. In International conference on machine learning (pp. 9323-9332). PMLR.
